# %% [markdown]
# # 7 Bayesian Network using an API
# Write a program to construct aBayesian network considering medical data. Use this model to
# demonstrate the diagnosis of heart patients using standard Heart Disease Data Set. You can use
# Java/Python ML library classes/API.

# %%
import sys
from urllib.request import urlopen
import numpy as np
import pandas as pd

from pgmpy.estimators import MaximumLikelihoodEstimator
from pgmpy.models import BayesianModel

from pgmpy.inference import VariableElimination

# %%
heartDisease_df = pd.read_csv('heartDisease.csv')

# %%
heartDisease_df.drop(['ca', 'slope', 'thal', 'oldpeak'], axis=1, inplace=True)

# %%
heartDisease_df.replace('?', np.nan, inplace=True)

# %%
model = BayesianModel([('age', 'trestbps'),
('age', 'fbs'), ('sex', 'trestbps'),
('exang', 'trestbps'), ('trestbps', 'heartdisease'),
('fbs', 'heartdisease'), ('heartdisease', 'restecg'),
('heartdisease', 'thalach'), ('heartdisease', 'chol')])
# Learing CPDs using Maximum Likelihood Estimators
model.fit(heartDisease_df, estimator=MaximumLikelihoodEstimator)

# %%
print(model.get_cpds('age'))
print(model.get_cpds('chol'))
print(model.get_cpds('sex'))
model.get_independencies()
# Out:
# +---------+------------+
# | age(29) | 0.00330033 |
# +---------+------------+
# | age(34) | 0.00660066 |
# +---------+------------+
# | age(35) | 0.0132013  |
# +---------+------------+
# | age(37) | 0.00660066 |
# +---------+------------+
# | age(38) | 0.00990099 |
# +---------+------------+
# | age(39) | 0.0132013  |
# +---------+------------+
# | age(40) | 0.00990099 |
# +---------+------------+
# | age(41) | 0.0330033  |
# +---------+------------+
# | age(42) | 0.0264026  |
# +---------+------------+
# | age(43) | 0.0264026  |
# +---------+------------+
# | age(44) | 0.0363036  |
# +---------+------------+
# | age(45) | 0.0264026  |
# +---------+------------+
# | age(46) | 0.0231023  |
# +---------+------------+
# | age(47) | 0.0165017  |
# +---------+------------+
# | age(48) | 0.0231023  |
# +---------+------------+
# | age(49) | 0.0165017  |
# +---------+------------+
# | age(50) | 0.0231023  |
# +---------+------------+
# | age(51) | 0.039604   |
# +---------+------------+
# | age(52) | 0.0429043  |
# +---------+------------+
# | age(53) | 0.0264026  |
# +---------+------------+
# | age(54) | 0.0528053  |
# +---------+------------+
# | age(55) | 0.0264026  |
# +---------+------------+
# | age(56) | 0.0363036  |
# +---------+------------+
# | age(57) | 0.0561056  |
# +---------+------------+
# | age(58) | 0.0627063  |
# +---------+------------+
# | age(59) | 0.0462046  |
# +---------+------------+
# | age(60) | 0.0363036  |
# +---------+------------+
# | age(61) | 0.0264026  |
# +---------+------------+
# | age(62) | 0.0363036  |
# +---------+------------+
# | age(63) | 0.029703   |
# +---------+------------+
# | age(64) | 0.0330033  |
# +---------+------------+
# | age(65) | 0.0264026  |
# +---------+------------+
# | age(66) | 0.0231023  |
# +---------+------------+
# | age(67) | 0.029703   |
# +---------+------------+
# | age(68) | 0.0132013  |
# +---------+------------+
# | age(69) | 0.00990099 |
# +---------+------------+
# | age(70) | 0.0132013  |
# +---------+------------+
# | age(71) | 0.00990099 |
# +---------+------------+
# | age(74) | 0.00330033 |
# +---------+------------+
# | age(76) | 0.00330033 |
# +---------+------------+
# | age(77) | 0.00330033 |
# +---------+------------+
# +--------------+----------------------+----------------------+
# | heartdisease | heartdisease(0)      | heartdisease(1)      |
# +--------------+----------------------+----------------------+
# | chol(126)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(131)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(141)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(149)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(157)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(160)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(164)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(166)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(167)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(168)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(169)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(172)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(174)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(175)    | 0.0                  | 0.01818181818181818  |
# +--------------+----------------------+----------------------+
# | chol(176)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(177)    | 0.014492753623188406 | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(178)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(180)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(182)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(183)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(184)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(185)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(186)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(187)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(188)    | 0.014492753623188406 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(192)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(193)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(195)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(196)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(197)    | 0.014492753623188406 | 0.024242424242424242 |
# +--------------+----------------------+----------------------+
# | chol(198)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(199)    | 0.0                  | 0.01818181818181818  |
# +--------------+----------------------+----------------------+
# | chol(200)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(201)    | 0.0                  | 0.01818181818181818  |
# +--------------+----------------------+----------------------+
# | chol(203)    | 0.014492753623188406 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(204)    | 0.014492753623188406 | 0.024242424242424242 |
# +--------------+----------------------+----------------------+
# | chol(205)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(206)    | 0.014492753623188406 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(207)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(208)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(209)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(210)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(211)    | 0.0                  | 0.024242424242424242 |
# +--------------+----------------------+----------------------+
# | chol(212)    | 0.028985507246376812 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(213)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(214)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(215)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(216)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(217)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(218)    | 0.014492753623188406 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(219)    | 0.007246376811594203 | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(220)    | 0.0                  | 0.01818181818181818  |
# +--------------+----------------------+----------------------+
# | chol(221)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(222)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(223)    | 0.007246376811594203 | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(224)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(225)    | 0.014492753623188406 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(226)    | 0.0                  | 0.024242424242424242 |
# +--------------+----------------------+----------------------+
# | chol(227)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(228)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(229)    | 0.021739130434782608 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(230)    | 0.021739130434782608 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(231)    | 0.014492753623188406 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(232)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(233)    | 0.007246376811594203 | 0.01818181818181818  |
# +--------------+----------------------+----------------------+
# | chol(234)    | 0.014492753623188406 | 0.024242424242424242 |
# +--------------+----------------------+----------------------+
# | chol(235)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(236)    | 0.007246376811594203 | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(237)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(239)    | 0.014492753623188406 | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(240)    | 0.0                  | 0.024242424242424242 |
# +--------------+----------------------+----------------------+
# | chol(241)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(242)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(243)    | 0.014492753623188406 | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(244)    | 0.007246376811594203 | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(245)    | 0.0                  | 0.01818181818181818  |
# +--------------+----------------------+----------------------+
# | chol(246)    | 0.014492753623188406 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(247)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(248)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(249)    | 0.021739130434782608 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(250)    | 0.0                  | 0.01818181818181818  |
# +--------------+----------------------+----------------------+
# | chol(252)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(253)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(254)    | 0.028985507246376812 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(255)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(256)    | 0.014492753623188406 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(257)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(258)    | 0.014492753623188406 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(259)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(260)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(261)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(262)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(263)    | 0.007246376811594203 | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(264)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(265)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(266)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(267)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(268)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(269)    | 0.014492753623188406 | 0.01818181818181818  |
# +--------------+----------------------+----------------------+
# | chol(270)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(271)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(273)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(274)    | 0.021739130434782608 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(275)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(276)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(277)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(278)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(281)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(282)    | 0.028985507246376812 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(283)    | 0.014492753623188406 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(284)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(286)    | 0.014492753623188406 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(288)    | 0.014492753623188406 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(289)    | 0.014492753623188406 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(290)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(293)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(294)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(295)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(298)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(299)    | 0.014492753623188406 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(300)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(302)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(303)    | 0.0                  | 0.01818181818181818  |
# +--------------+----------------------+----------------------+
# | chol(304)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(305)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(306)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(307)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(308)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(309)    | 0.014492753623188406 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(311)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(313)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(315)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(318)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(319)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(321)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(322)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(325)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(326)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(327)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(330)    | 0.014492753623188406 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(335)    | 0.014492753623188406 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(340)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(341)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(342)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(353)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(354)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(360)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(394)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(407)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(409)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(417)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(564)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# +--------+----------+
# | sex(0) | 0.316832 |
# +--------+----------+
# | sex(1) | 0.683168 |
# +--------+----------+
# (age _|_ exang, sex)
# (age _|_ sex | exang)
# (age _|_ exang, sex | fbs)
# (age _|_ exang | sex)
# (age _|_ chol, thalach, restecg | heartdisease)
# (age _|_ sex | exang, fbs)
# (age _|_ chol, thalach, restecg | exang, heartdisease)
# (age _|_ exang | fbs, sex)
# (age _|_ heartdisease, chol, thalach, restecg | fbs, trestbps)
# (age _|_ chol, thalach, restecg | fbs, heartdisease)
# (age _|_ chol, restecg | heartdisease, thalach)
# (age _|_ chol, thalach, restecg | heartdisease, sex)
# (age _|_ chol, thalach, restecg | heartdisease, trestbps)
# (age _|_ chol, thalach | heartdisease, restecg)
# (age _|_ thalach, restecg | heartdisease, chol)
# (age _|_ heartdisease, chol, thalach, restecg | exang, fbs, trestbps)
# (age _|_ chol, thalach, restecg | exang, heartdisease, fbs)
# (age _|_ chol, restecg | exang, heartdisease, thalach)
# (age _|_ chol, thalach, restecg | exang, heartdisease, sex)
# (age _|_ chol, thalach, restecg | exang, heartdisease, trestbps)
# (age _|_ chol, thalach | exang, heartdisease, restecg)
# (age _|_ thalach, restecg | exang, chol, heartdisease)
# (age _|_ heartdisease, chol, restecg | fbs, thalach, trestbps)
# (age _|_ chol, restecg | fbs, heartdisease, thalach)
# (age _|_ heartdisease, chol, thalach, restecg | fbs, trestbps, sex)
# (age _|_ chol, thalach, restecg | fbs, heartdisease, sex)
# (age _|_ heartdisease, chol, thalach | fbs, restecg, trestbps)
# (age _|_ heartdisease, thalach, restecg | fbs, chol, trestbps)
# (age _|_ chol, thalach, restecg | fbs, heartdisease, trestbps)
# (age _|_ chol, thalach | fbs, heartdisease, restecg)
# (age _|_ thalach, restecg | fbs, chol, heartdisease)
# (age _|_ chol, restecg | heartdisease, thalach, sex)
# (age _|_ chol, restecg | heartdisease, thalach, trestbps)
# (age _|_ chol | heartdisease, thalach, restecg)
# (age _|_ restecg | heartdisease, chol, thalach)
# (age _|_ chol, thalach, restecg | heartdisease, trestbps, sex)
# (age _|_ chol, thalach | restecg, heartdisease, sex)
# (age _|_ thalach, restecg | heartdisease, chol, sex)
# (age _|_ chol, thalach | restecg, heartdisease, trestbps)
# (age _|_ thalach, restecg | heartdisease, chol, trestbps)
# (age _|_ thalach | heartdisease, chol, restecg)
# (age _|_ heartdisease, chol, restecg | exang, fbs, thalach, trestbps)
# (age _|_ chol, restecg | exang, heartdisease, fbs, thalach)
# (age _|_ heartdisease, chol, thalach, restecg | exang, fbs, trestbps, sex)
# (age _|_ chol, thalach, restecg | exang, heartdisease, fbs, sex)
# (age _|_ heartdisease, chol, thalach | exang, fbs, restecg, trestbps)
# (age _|_ heartdisease, thalach, restecg | exang, chol, fbs, trestbps)
# (age _|_ chol, thalach, restecg | exang, heartdisease, fbs, trestbps)
# (age _|_ chol, thalach | exang, heartdisease, fbs, restecg)
# (age _|_ thalach, restecg | exang, chol, heartdisease, fbs)
# (age _|_ chol, restecg | exang, heartdisease, thalach, sex)
# (age _|_ chol, restecg | exang, heartdisease, thalach, trestbps)
# (age _|_ chol | exang, heartdisease, thalach, restecg)
# (age _|_ restecg | exang, chol, heartdisease, thalach)
# (age _|_ chol, thalach, restecg | exang, heartdisease, trestbps, sex)
# (age _|_ chol, thalach | exang, heartdisease, restecg, sex)
# (age _|_ thalach, restecg | exang, chol, heartdisease, sex)
# (age _|_ chol, thalach | exang, heartdisease, restecg, trestbps)
# (age _|_ thalach, restecg | exang, chol, heartdisease, trestbps)
# (age _|_ thalach | exang, chol, heartdisease, restecg)
# (age _|_ heartdisease, chol, restecg | fbs, thalach, trestbps, sex)
# (age _|_ chol, restecg | fbs, heartdisease, thalach, sex)
# (age _|_ heartdisease, chol | fbs, thalach, restecg, trestbps)
# (age _|_ heartdisease, restecg | fbs, chol, thalach, trestbps)
# (age _|_ chol, restecg | fbs, heartdisease, thalach, trestbps)
# (age _|_ chol | fbs, heartdisease, thalach, restecg)
# (age _|_ restecg | fbs, chol, heartdisease, thalach)
# (age _|_ heartdisease, chol, thalach | fbs, restecg, trestbps, sex)
# (age _|_ heartdisease, thalach, restecg | fbs, chol, trestbps, sex)
# (age _|_ chol, thalach, restecg | fbs, heartdisease, trestbps, sex)
# (age _|_ chol, thalach | fbs, heartdisease, restecg, sex)
# (age _|_ thalach, restecg | fbs, chol, heartdisease, sex)
# (age _|_ heartdisease, thalach | fbs, chol, restecg, trestbps)
# (age _|_ chol, thalach | fbs, heartdisease, restecg, trestbps)
# (age _|_ thalach, restecg | fbs, chol, heartdisease, trestbps)
# (age _|_ thalach | fbs, chol, heartdisease, restecg)
# (age _|_ chol, restecg | heartdisease, thalach, trestbps, sex)
# (age _|_ chol | restecg, heartdisease, thalach, sex)
# (age _|_ restecg | heartdisease, chol, thalach, sex)
# (age _|_ chol | restecg, heartdisease, thalach, trestbps)
# (age _|_ restecg | heartdisease, chol, thalach, trestbps)
# (age _|_ chol, thalach | restecg, heartdisease, trestbps, sex)
# (age _|_ thalach, restecg | heartdisease, chol, trestbps, sex)
# (age _|_ thalach | restecg, chol, heartdisease, sex)
# (age _|_ thalach | restecg, chol, heartdisease, trestbps)
# (age _|_ heartdisease, chol, restecg | exang, fbs, thalach, trestbps, sex)
# (age _|_ chol, restecg | exang, fbs, thalach, sex, heartdisease)
# (age _|_ heartdisease, chol | exang, fbs, thalach, restecg, trestbps)
# (age _|_ heartdisease, restecg | exang, fbs, thalach, trestbps, chol)
# (age _|_ chol, restecg | exang, fbs, thalach, trestbps, heartdisease)
# (age _|_ chol | exang, fbs, thalach, restecg, heartdisease)
# (age _|_ restecg | exang, fbs, thalach, chol, heartdisease)
# (age _|_ heartdisease, chol, thalach | exang, fbs, restecg, trestbps, sex)
# (age _|_ heartdisease, thalach, restecg | exang, fbs, trestbps, sex, chol)
# (age _|_ chol, thalach, restecg | exang, fbs, trestbps, sex, heartdisease)
# (age _|_ chol, thalach | exang, fbs, restecg, sex, heartdisease)
# (age _|_ thalach, restecg | exang, fbs, sex, chol, heartdisease)
# (age _|_ heartdisease, thalach | exang, fbs, restecg, trestbps, chol)
# (age _|_ chol, thalach | exang, fbs, restecg, trestbps, heartdisease)
# (age _|_ thalach, restecg | exang, fbs, trestbps, chol, heartdisease)
# (age _|_ thalach | exang, fbs, restecg, chol, heartdisease)
# (age _|_ chol, restecg | exang, thalach, trestbps, sex, heartdisease)
# (age _|_ chol | exang, thalach, restecg, sex, heartdisease)
# (age _|_ restecg | exang, thalach, sex, chol, heartdisease)
# (age _|_ chol | exang, thalach, restecg, trestbps, heartdisease)
# (age _|_ restecg | exang, thalach, trestbps, chol, heartdisease)
# (age _|_ chol, thalach | exang, restecg, trestbps, sex, heartdisease)
# (age _|_ thalach, restecg | exang, trestbps, sex, chol, heartdisease)
# (age _|_ thalach | exang, restecg, sex, chol, heartdisease)
# (age _|_ thalach | exang, restecg, trestbps, chol, heartdisease)
# (age _|_ heartdisease, chol | fbs, thalach, restecg, trestbps, sex)
# (age _|_ heartdisease, restecg | fbs, thalach, trestbps, sex, chol)
# (age _|_ chol, restecg | fbs, thalach, trestbps, sex, heartdisease)
# (age _|_ chol | fbs, thalach, restecg, sex, heartdisease)
# (age _|_ restecg | fbs, thalach, sex, chol, heartdisease)
# (age _|_ heartdisease | fbs, thalach, restecg, trestbps, chol)
# (age _|_ chol | fbs, thalach, restecg, trestbps, heartdisease)
# (age _|_ restecg | fbs, thalach, trestbps, chol, heartdisease)
# (age _|_ heartdisease, thalach | fbs, restecg, trestbps, sex, chol)
# (age _|_ chol, thalach | fbs, restecg, trestbps, sex, heartdisease)
# (age _|_ thalach, restecg | fbs, trestbps, sex, chol, heartdisease)
# (age _|_ thalach | fbs, restecg, sex, chol, heartdisease)
# (age _|_ thalach | fbs, restecg, trestbps, chol, heartdisease)
# (age _|_ chol | thalach, restecg, trestbps, sex, heartdisease)
# (age _|_ restecg | thalach, trestbps, sex, chol, heartdisease)
# (age _|_ thalach | restecg, trestbps, sex, chol, heartdisease)
# (age _|_ heartdisease, chol | exang, fbs, thalach, trestbps, sex, restecg)
# (age _|_ heartdisease, restecg | exang, fbs, thalach, trestbps, sex, chol)
# (age _|_ chol, restecg | exang, fbs, thalach, trestbps, sex, heartdisease)
# (age _|_ chol | exang, fbs, thalach, restecg, sex, heartdisease)
# (age _|_ restecg | exang, fbs, thalach, sex, chol, heartdisease)
# (age _|_ heartdisease | exang, fbs, thalach, restecg, trestbps, chol)
# (age _|_ chol | exang, fbs, thalach, restecg, trestbps, heartdisease)
# (age _|_ restecg | exang, fbs, thalach, trestbps, chol, heartdisease)
# (age _|_ heartdisease, thalach | exang, fbs, restecg, trestbps, sex, chol)
# (age _|_ chol, thalach | exang, fbs, restecg, trestbps, sex, heartdisease)
# (age _|_ thalach, restecg | exang, fbs, trestbps, sex, chol, heartdisease)
# (age _|_ thalach | exang, fbs, restecg, sex, chol, heartdisease)
# (age _|_ thalach | exang, fbs, restecg, trestbps, chol, heartdisease)
# (age _|_ chol | exang, thalach, restecg, trestbps, sex, heartdisease)
# (age _|_ restecg | exang, thalach, trestbps, sex, chol, heartdisease)
# (age _|_ thalach | exang, restecg, trestbps, sex, chol, heartdisease)
# (age _|_ heartdisease | fbs, thalach, restecg, trestbps, sex, chol)
# (age _|_ chol | fbs, thalach, restecg, trestbps, sex, heartdisease)
# (age _|_ restecg | fbs, thalach, trestbps, sex, chol, heartdisease)
# (age _|_ thalach | fbs, restecg, trestbps, sex, chol, heartdisease)
# (age _|_ heartdisease | exang, fbs, thalach, trestbps, sex, restecg, chol)
# (age _|_ chol | exang, fbs, thalach, trestbps, sex, restecg, heartdisease)
# (age _|_ restecg | exang, fbs, thalach, trestbps, sex, chol, heartdisease)
# (age _|_ thalach | exang, fbs, restecg, trestbps, sex, chol, heartdisease)
# (trestbps _|_ fbs | age)
# (trestbps _|_ chol, thalach, restecg | heartdisease)
# (trestbps _|_ fbs | exang, age)
# (trestbps _|_ chol, thalach, restecg | exang, heartdisease)
# (trestbps _|_ chol, thalach, restecg | fbs, heartdisease)
# (trestbps _|_ fbs | age, sex)
# (trestbps _|_ chol, thalach, restecg | heartdisease, age)
# (trestbps _|_ chol, restecg | heartdisease, thalach)
# (trestbps _|_ chol, thalach, restecg | heartdisease, sex)
# (trestbps _|_ chol, thalach | heartdisease, restecg)
# (trestbps _|_ thalach, restecg | heartdisease, chol)
# (trestbps _|_ chol, thalach, restecg | exang, heartdisease, fbs)
# (trestbps _|_ fbs | exang, age, sex)
# (trestbps _|_ chol, thalach, restecg | exang, age, heartdisease)
# (trestbps _|_ chol, restecg | exang, heartdisease, thalach)
# (trestbps _|_ chol, thalach, restecg | exang, heartdisease, sex)
# (trestbps _|_ chol, thalach | exang, heartdisease, restecg)
# (trestbps _|_ thalach, restecg | exang, chol, heartdisease)
# (trestbps _|_ chol, thalach, restecg | fbs, age, heartdisease)
# (trestbps _|_ chol, restecg | fbs, heartdisease, thalach)
# (trestbps _|_ chol, thalach, restecg | fbs, heartdisease, sex)
# (trestbps _|_ chol, thalach | fbs, heartdisease, restecg)
# (trestbps _|_ thalach, restecg | fbs, chol, heartdisease)
# (trestbps _|_ chol, restecg | heartdisease, age, thalach)
# (trestbps _|_ chol, thalach, restecg | heartdisease, age, sex)
# (trestbps _|_ chol, thalach | heartdisease, age, restecg)
# (trestbps _|_ thalach, restecg | heartdisease, age, chol)
# (trestbps _|_ chol, restecg | heartdisease, thalach, sex)
# (trestbps _|_ chol | heartdisease, thalach, restecg)
# (trestbps _|_ restecg | heartdisease, chol, thalach)
# (trestbps _|_ chol, thalach | restecg, heartdisease, sex)
# (trestbps _|_ thalach, restecg | heartdisease, chol, sex)
# (trestbps _|_ thalach | heartdisease, chol, restecg)
# (trestbps _|_ chol, thalach, restecg | exang, age, heartdisease, fbs)
# (trestbps _|_ chol, restecg | exang, heartdisease, fbs, thalach)
# (trestbps _|_ chol, thalach, restecg | exang, heartdisease, fbs, sex)
# (trestbps _|_ chol, thalach | exang, heartdisease, fbs, restecg)
# (trestbps _|_ thalach, restecg | exang, chol, heartdisease, fbs)
# (trestbps _|_ chol, restecg | exang, age, heartdisease, thalach)
# (trestbps _|_ chol, thalach, restecg | exang, age, heartdisease, sex)
# (trestbps _|_ chol, thalach | exang, age, heartdisease, restecg)
# (trestbps _|_ thalach, restecg | exang, age, heartdisease, chol)
# (trestbps _|_ chol, restecg | exang, heartdisease, thalach, sex)
# (trestbps _|_ chol | exang, heartdisease, thalach, restecg)
# (trestbps _|_ restecg | exang, chol, heartdisease, thalach)
# (trestbps _|_ chol, thalach | exang, heartdisease, restecg, sex)
# (trestbps _|_ thalach, restecg | exang, chol, heartdisease, sex)
# (trestbps _|_ thalach | exang, chol, heartdisease, restecg)
# (trestbps _|_ chol, restecg | fbs, age, heartdisease, thalach)
# (trestbps _|_ chol, thalach, restecg | fbs, age, heartdisease, sex)
# (trestbps _|_ chol, thalach | fbs, age, heartdisease, restecg)
# (trestbps _|_ thalach, restecg | fbs, age, heartdisease, chol)
# (trestbps _|_ chol, restecg | fbs, heartdisease, thalach, sex)
# (trestbps _|_ chol | fbs, heartdisease, thalach, restecg)
# (trestbps _|_ restecg | fbs, chol, heartdisease, thalach)
# (trestbps _|_ chol, thalach | fbs, heartdisease, restecg, sex)
# (trestbps _|_ thalach, restecg | fbs, chol, heartdisease, sex)
# (trestbps _|_ thalach | fbs, chol, heartdisease, restecg)
# (trestbps _|_ chol, restecg | heartdisease, age, thalach, sex)
# (trestbps _|_ chol | heartdisease, age, thalach, restecg)
# (trestbps _|_ restecg | chol, age, heartdisease, thalach)
# (trestbps _|_ chol, thalach | restecg, age, heartdisease, sex)
# (trestbps _|_ thalach, restecg | heartdisease, age, chol, sex)
# (trestbps _|_ thalach | heartdisease, age, chol, restecg)
# (trestbps _|_ chol | restecg, heartdisease, thalach, sex)
# (trestbps _|_ restecg | heartdisease, chol, thalach, sex)
# (trestbps _|_ thalach | restecg, chol, heartdisease, sex)
# (trestbps _|_ chol, restecg | exang, fbs, age, thalach, heartdisease)
# (trestbps _|_ chol, thalach, restecg | exang, fbs, age, sex, heartdisease)
# (trestbps _|_ chol, thalach | exang, fbs, age, restecg, heartdisease)
# (trestbps _|_ thalach, restecg | exang, fbs, age, chol, heartdisease)
# (trestbps _|_ chol, restecg | exang, fbs, thalach, sex, heartdisease)
# (trestbps _|_ chol | exang, fbs, thalach, restecg, heartdisease)
# (trestbps _|_ restecg | exang, fbs, thalach, chol, heartdisease)
# (trestbps _|_ chol, thalach | exang, fbs, restecg, sex, heartdisease)
# (trestbps _|_ thalach, restecg | exang, fbs, sex, chol, heartdisease)
# (trestbps _|_ thalach | exang, fbs, restecg, chol, heartdisease)
# (trestbps _|_ chol, restecg | exang, age, thalach, sex, heartdisease)
# (trestbps _|_ chol | exang, age, thalach, restecg, heartdisease)
# (trestbps _|_ restecg | exang, age, thalach, chol, heartdisease)
# (trestbps _|_ chol, thalach | exang, age, restecg, sex, heartdisease)
# (trestbps _|_ thalach, restecg | exang, age, sex, chol, heartdisease)
# (trestbps _|_ thalach | exang, age, restecg, chol, heartdisease)
# (trestbps _|_ chol | exang, thalach, restecg, sex, heartdisease)
# (trestbps _|_ restecg | exang, thalach, sex, chol, heartdisease)
# (trestbps _|_ thalach | exang, restecg, sex, chol, heartdisease)
# (trestbps _|_ chol, restecg | fbs, age, thalach, sex, heartdisease)
# (trestbps _|_ chol | fbs, age, thalach, restecg, heartdisease)
# (trestbps _|_ restecg | fbs, age, thalach, chol, heartdisease)
# (trestbps _|_ chol, thalach | fbs, age, restecg, sex, heartdisease)
# (trestbps _|_ thalach, restecg | fbs, age, sex, chol, heartdisease)
# (trestbps _|_ thalach | fbs, age, restecg, chol, heartdisease)
# (trestbps _|_ chol | fbs, thalach, restecg, sex, heartdisease)
# (trestbps _|_ restecg | fbs, thalach, sex, chol, heartdisease)
# (trestbps _|_ thalach | fbs, restecg, sex, chol, heartdisease)
# (trestbps _|_ chol | age, thalach, restecg, sex, heartdisease)
# (trestbps _|_ restecg | age, thalach, sex, chol, heartdisease)
# (trestbps _|_ thalach | age, restecg, sex, chol, heartdisease)
# (trestbps _|_ chol, restecg | exang, fbs, age, thalach, sex, heartdisease)
# (trestbps _|_ chol | exang, fbs, age, thalach, restecg, heartdisease)
# (trestbps _|_ restecg | exang, fbs, age, thalach, chol, heartdisease)
# (trestbps _|_ chol, thalach | exang, fbs, age, restecg, sex, heartdisease)
# (trestbps _|_ thalach, restecg | exang, fbs, age, sex, chol, heartdisease)
# (trestbps _|_ thalach | exang, fbs, age, restecg, chol, heartdisease)
# (trestbps _|_ chol | exang, fbs, thalach, restecg, sex, heartdisease)
# (trestbps _|_ restecg | exang, fbs, thalach, sex, chol, heartdisease)
# (trestbps _|_ thalach | exang, fbs, restecg, sex, chol, heartdisease)
# (trestbps _|_ chol | exang, age, thalach, restecg, sex, heartdisease)
# (trestbps _|_ restecg | exang, age, thalach, sex, chol, heartdisease)
# (trestbps _|_ thalach | exang, age, restecg, sex, chol, heartdisease)
# (trestbps _|_ chol | fbs, age, thalach, restecg, sex, heartdisease)
# (trestbps _|_ restecg | fbs, age, thalach, sex, chol, heartdisease)
# (trestbps _|_ thalach | fbs, age, restecg, sex, chol, heartdisease)
# (trestbps _|_ chol | exang, fbs, age, thalach, sex, restecg, heartdisease)
# (trestbps _|_ restecg | exang, fbs, age, thalach, sex, chol, heartdisease)
# (trestbps _|_ thalach | exang, fbs, age, restecg, sex, chol, heartdisease)
# (fbs _|_ exang, sex)
# (fbs _|_ sex | exang)
# (fbs _|_ exang, trestbps, sex | age)
# (fbs _|_ exang | sex)
# (fbs _|_ chol, thalach, restecg | heartdisease)
# (fbs _|_ sex, trestbps | exang, age)
# (fbs _|_ chol, thalach, restecg | exang, heartdisease)
# (fbs _|_ exang, trestbps | age, sex)
# (fbs _|_ exang, sex | age, trestbps)
# (fbs _|_ chol, thalach, restecg | heartdisease, age)
# (fbs _|_ chol, restecg | heartdisease, thalach)
# (fbs _|_ chol, thalach, restecg | heartdisease, sex)
# (fbs _|_ chol, thalach, restecg | heartdisease, trestbps)
# (fbs _|_ chol, thalach | heartdisease, restecg)
# (fbs _|_ thalach, restecg | heartdisease, chol)
# (fbs _|_ trestbps | exang, age, sex)
# (fbs _|_ sex | exang, age, trestbps)
# (fbs _|_ chol, thalach, restecg | exang, age, heartdisease)
# (fbs _|_ chol, restecg | exang, heartdisease, thalach)
# (fbs _|_ chol, thalach, restecg | exang, heartdisease, sex)
# (fbs _|_ chol, thalach, restecg | exang, heartdisease, trestbps)
# (fbs _|_ chol, thalach | exang, heartdisease, restecg)
# (fbs _|_ thalach, restecg | exang, chol, heartdisease)
# (fbs _|_ exang, sex | age, thalach, trestbps)
# (fbs _|_ chol, restecg | heartdisease, age, thalach)
# (fbs _|_ exang | age, trestbps, sex)
# (fbs _|_ chol, thalach, restecg | heartdisease, age, sex)
# (fbs _|_ exang, sex | restecg, age, trestbps)
# (fbs _|_ exang, sex | age, chol, trestbps)
# (fbs _|_ exang, restecg, chol, thalach, sex | heartdisease, age, trestbps)
# (fbs _|_ chol, thalach | heartdisease, age, restecg)
# (fbs _|_ thalach, restecg | heartdisease, age, chol)
# (fbs _|_ chol, restecg | heartdisease, thalach, sex)
# (fbs _|_ chol, restecg | heartdisease, thalach, trestbps)
# (fbs _|_ chol | heartdisease, thalach, restecg)
# (fbs _|_ restecg | heartdisease, chol, thalach)
# (fbs _|_ chol, thalach, restecg | heartdisease, trestbps, sex)
# (fbs _|_ chol, thalach | restecg, heartdisease, sex)
# (fbs _|_ thalach, restecg | heartdisease, chol, sex)
# (fbs _|_ chol, thalach | restecg, heartdisease, trestbps)
# (fbs _|_ thalach, restecg | heartdisease, chol, trestbps)
# (fbs _|_ thalach | heartdisease, chol, restecg)
# (fbs _|_ sex | exang, age, thalach, trestbps)
# (fbs _|_ chol, restecg | exang, age, heartdisease, thalach)
# (fbs _|_ chol, thalach, restecg | exang, age, heartdisease, sex)
# (fbs _|_ sex | exang, age, restecg, trestbps)
# (fbs _|_ sex | exang, age, chol, trestbps)
# (fbs _|_ sex, chol, thalach, restecg | exang, age, heartdisease, trestbps)
# (fbs _|_ chol, thalach | exang, age, heartdisease, restecg)
# (fbs _|_ thalach, restecg | exang, age, heartdisease, chol)
# (fbs _|_ chol, restecg | exang, heartdisease, thalach, sex)
# (fbs _|_ chol, restecg | exang, heartdisease, thalach, trestbps)
# (fbs _|_ chol | exang, heartdisease, thalach, restecg)
# (fbs _|_ restecg | exang, chol, heartdisease, thalach)
# (fbs _|_ chol, thalach, restecg | exang, heartdisease, trestbps, sex)
# (fbs _|_ chol, thalach | exang, heartdisease, restecg, sex)
# (fbs _|_ thalach, restecg | exang, chol, heartdisease, sex)
# (fbs _|_ chol, thalach | exang, heartdisease, restecg, trestbps)
# (fbs _|_ thalach, restecg | exang, chol, heartdisease, trestbps)
# (fbs _|_ thalach | exang, chol, heartdisease, restecg)
# (fbs _|_ exang | age, thalach, trestbps, sex)
# (fbs _|_ chol, restecg | heartdisease, age, thalach, sex)
# (fbs _|_ exang, sex | restecg, age, thalach, trestbps)
# (fbs _|_ exang, sex | chol, age, thalach, trestbps)
# (fbs _|_ exang, chol, sex, restecg | heartdisease, age, thalach, trestbps)
# (fbs _|_ chol | heartdisease, age, thalach, restecg)
# (fbs _|_ restecg | chol, age, heartdisease, thalach)
# (fbs _|_ exang | restecg, age, trestbps, sex)
# (fbs _|_ exang | age, chol, trestbps, sex)
# (fbs _|_ exang, chol, thalach, restecg | heartdisease, age, trestbps, sex)
# (fbs _|_ chol, thalach | restecg, age, heartdisease, sex)
# (fbs _|_ thalach, restecg | heartdisease, age, chol, sex)
# (fbs _|_ exang, sex | restecg, age, chol, trestbps)
# (fbs _|_ exang, chol, thalach, sex | restecg, age, heartdisease, trestbps)
# (fbs _|_ exang, sex, thalach, restecg | heartdisease, age, chol, trestbps)
# (fbs _|_ thalach | heartdisease, age, chol, restecg)
# (fbs _|_ chol, restecg | heartdisease, thalach, trestbps, sex)
# (fbs _|_ chol | restecg, heartdisease, thalach, sex)
# (fbs _|_ restecg | heartdisease, chol, thalach, sex)
# (fbs _|_ chol | restecg, heartdisease, thalach, trestbps)
# (fbs _|_ restecg | heartdisease, chol, thalach, trestbps)
# (fbs _|_ chol, thalach | restecg, heartdisease, trestbps, sex)
# (fbs _|_ thalach, restecg | heartdisease, chol, trestbps, sex)
# (fbs _|_ thalach | restecg, chol, heartdisease, sex)
# (fbs _|_ thalach | restecg, chol, heartdisease, trestbps)
# (fbs _|_ chol, restecg | exang, age, thalach, sex, heartdisease)
# (fbs _|_ sex | exang, age, thalach, restecg, trestbps)
# (fbs _|_ sex | exang, age, thalach, trestbps, chol)
# (fbs _|_ sex, chol, restecg | exang, age, thalach, trestbps, heartdisease)
# (fbs _|_ chol | exang, age, thalach, restecg, heartdisease)
# (fbs _|_ restecg | exang, age, thalach, chol, heartdisease)
# (fbs _|_ chol, thalach, restecg | exang, age, trestbps, sex, heartdisease)
# (fbs _|_ chol, thalach | exang, age, restecg, sex, heartdisease)
# (fbs _|_ thalach, restecg | exang, age, sex, chol, heartdisease)
# (fbs _|_ sex | exang, age, restecg, trestbps, chol)
# (fbs _|_ chol, thalach, sex | exang, age, restecg, trestbps, heartdisease)
# (fbs _|_ sex, thalach, restecg | exang, age, trestbps, chol, heartdisease)
# (fbs _|_ thalach | exang, age, restecg, chol, heartdisease)
# (fbs _|_ chol, restecg | exang, thalach, trestbps, sex, heartdisease)
# (fbs _|_ chol | exang, thalach, restecg, sex, heartdisease)
# (fbs _|_ restecg | exang, thalach, sex, chol, heartdisease)
# (fbs _|_ chol | exang, thalach, restecg, trestbps, heartdisease)
# (fbs _|_ restecg | exang, thalach, trestbps, chol, heartdisease)
# (fbs _|_ chol, thalach | exang, restecg, trestbps, sex, heartdisease)
# (fbs _|_ thalach, restecg | exang, trestbps, sex, chol, heartdisease)
# (fbs _|_ thalach | exang, restecg, sex, chol, heartdisease)
# (fbs _|_ thalach | exang, restecg, trestbps, chol, heartdisease)
# (fbs _|_ exang | age, thalach, restecg, trestbps, sex)
# (fbs _|_ exang | age, thalach, trestbps, sex, chol)
# (fbs _|_ exang, chol, restecg | age, thalach, trestbps, sex, heartdisease)
# (fbs _|_ chol | age, thalach, restecg, sex, heartdisease)
# (fbs _|_ restecg | age, thalach, sex, chol, heartdisease)
# (fbs _|_ exang, sex | age, thalach, restecg, trestbps, chol)
# (fbs _|_ exang, chol, sex | age, thalach, restecg, trestbps, heartdisease)
# (fbs _|_ exang, sex, restecg | age, thalach, trestbps, chol, heartdisease)
# (fbs _|_ exang | age, restecg, trestbps, sex, chol)
# (fbs _|_ exang, chol, thalach | age, restecg, trestbps, sex, heartdisease)
# (fbs _|_ exang, thalach, restecg | age, trestbps, sex, chol, heartdisease)
# (fbs _|_ thalach | age, restecg, sex, chol, heartdisease)
# (fbs _|_ exang, thalach, sex | age, restecg, trestbps, chol, heartdisease)
# (fbs _|_ chol | thalach, restecg, trestbps, sex, heartdisease)
# (fbs _|_ restecg | thalach, trestbps, sex, chol, heartdisease)
# (fbs _|_ thalach | restecg, trestbps, sex, chol, heartdisease)
# (fbs _|_ chol, restecg | exang, age, thalach, trestbps, sex, heartdisease)
# (fbs _|_ chol | exang, age, thalach, restecg, sex, heartdisease)
# (fbs _|_ restecg | exang, age, thalach, sex, chol, heartdisease)
# (fbs _|_ sex | exang, age, thalach, restecg, trestbps, chol)
# (fbs _|_ chol, sex | exang, age, thalach, restecg, trestbps, heartdisease)
# (fbs _|_ sex, restecg | exang, age, thalach, trestbps, chol, heartdisease)
# (fbs _|_ chol, thalach | exang, age, restecg, trestbps, sex, heartdisease)
# (fbs _|_ thalach, restecg | exang, age, trestbps, sex, chol, heartdisease)
# (fbs _|_ thalach | exang, age, restecg, sex, chol, heartdisease)
# (fbs _|_ thalach, sex | exang, age, restecg, trestbps, chol, heartdisease)
# (fbs _|_ chol | exang, thalach, restecg, trestbps, sex, heartdisease)
# (fbs _|_ restecg | exang, thalach, trestbps, sex, chol, heartdisease)
# (fbs _|_ thalach | exang, restecg, trestbps, sex, chol, heartdisease)
# (fbs _|_ exang | age, thalach, restecg, trestbps, sex, chol)
# (fbs _|_ exang, chol | age, thalach, restecg, trestbps, sex, heartdisease)
# (fbs _|_ exang, restecg | age, thalach, trestbps, sex, chol, heartdisease)
# (fbs _|_ exang, sex | age, thalach, restecg, trestbps, chol, heartdisease)
# (fbs _|_ exang, thalach | age, restecg, trestbps, sex, chol, heartdisease)
# (fbs _|_ chol | exang, age, thalach, trestbps, sex, restecg, heartdisease)
# (fbs _|_ restecg | exang, age, thalach, trestbps, sex, chol, heartdisease)
# (fbs _|_ sex | exang, age, thalach, restecg, trestbps, chol, heartdisease)
# (fbs _|_ thalach | exang, age, restecg, trestbps, sex, chol, heartdisease)
# (fbs _|_ exang | age, thalach, restecg, trestbps, sex, chol, heartdisease)
# (sex _|_ exang, age, fbs)
# (sex _|_ fbs, age | exang)
# (sex _|_ exang, age | fbs)
# (sex _|_ exang, fbs | age)
# (sex _|_ chol, thalach, restecg | heartdisease)
# (sex _|_ age | exang, fbs)
# (sex _|_ fbs | exang, age)
# (sex _|_ chol, thalach, restecg | exang, heartdisease)
# (sex _|_ exang | fbs, age)
# (sex _|_ heartdisease, chol, thalach, restecg | fbs, trestbps)
# (sex _|_ chol, thalach, restecg | fbs, heartdisease)
# (sex _|_ chol, fbs, heartdisease, thalach, restecg | age, trestbps)
# (sex _|_ chol, thalach, restecg | heartdisease, age)
# (sex _|_ chol, restecg | heartdisease, thalach)
# (sex _|_ chol, thalach, restecg | heartdisease, trestbps)
# (sex _|_ chol, thalach | heartdisease, restecg)
# (sex _|_ thalach, restecg | heartdisease, chol)
# (sex _|_ heartdisease, chol, thalach, restecg | exang, fbs, trestbps)
# (sex _|_ chol, thalach, restecg | exang, heartdisease, fbs)
# (sex _|_ chol, fbs, heartdisease, thalach, restecg | exang, age, trestbps)
# (sex _|_ chol, thalach, restecg | exang, age, heartdisease)
# (sex _|_ chol, restecg | exang, heartdisease, thalach)
# (sex _|_ chol, thalach, restecg | exang, heartdisease, trestbps)
# (sex _|_ chol, thalach | exang, heartdisease, restecg)
# (sex _|_ thalach, restecg | exang, chol, heartdisease)
# ...
# (thalach _|_ fbs, chol, trestbps | exang, age, restecg, sex, heartdisease)
# (thalach _|_ fbs, trestbps, restecg | exang, age, sex, chol, heartdisease)
# (thalach _|_ sex | exang, age, restecg, trestbps, chol)
# (thalach _|_ fbs, chol, sex | exang, age, restecg, trestbps, heartdisease)
# (thalach _|_ fbs, sex, restecg | exang, age, trestbps, chol, heartdisease)
# (thalach _|_ fbs, sex, trestbps | exang, age, restecg, chol, heartdisease)
# (thalach _|_ fbs, age, chol | exang, restecg, trestbps, sex, heartdisease)
# (thalach _|_ fbs, age, restecg | exang, trestbps, sex, chol, heartdisease)
# (thalach _|_ fbs, age, trestbps | exang, restecg, sex, chol, heartdisease)
# (thalach _|_ fbs, age, sex | exang, restecg, trestbps, chol, heartdisease)
# (thalach _|_ exang | fbs, age, restecg, trestbps, sex)
# (thalach _|_ exang | fbs, age, trestbps, sex, chol)
# (thalach _|_ exang, chol, restecg | fbs, age, trestbps, sex, heartdisease)
# (thalach _|_ exang, chol, trestbps | fbs, age, restecg, sex, heartdisease)
# (thalach _|_ exang, trestbps, restecg | fbs, age, sex, chol, heartdisease)
# (thalach _|_ exang, sex | fbs, age, restecg, trestbps, chol)
# (thalach _|_ exang, chol, sex | fbs, age, restecg, trestbps, heartdisease)
# (thalach _|_ exang, sex, restecg | fbs, age, trestbps, chol, heartdisease)
# (thalach _|_ exang, sex, trestbps | fbs, age, restecg, chol, heartdisease)
# (thalach _|_ exang, age | fbs, restecg, trestbps, sex, chol)
# (thalach _|_ exang, age, chol | fbs, restecg, trestbps, sex, heartdisease)
# (thalach _|_ exang, age, restecg | fbs, trestbps, sex, chol, heartdisease)
# (thalach _|_ exang, age, trestbps | fbs, restecg, sex, chol, heartdisease)
# (thalach _|_ exang, age, sex | fbs, restecg, trestbps, chol, heartdisease)
# (thalach _|_ exang | age, restecg, trestbps, sex, chol)
# (thalach _|_ exang, chol, fbs | age, restecg, trestbps, sex, heartdisease)
# (thalach _|_ exang, fbs, restecg | age, trestbps, sex, chol, heartdisease)
# (thalach _|_ exang, fbs, trestbps | age, restecg, sex, chol, heartdisease)
# (thalach _|_ exang, fbs, sex | age, restecg, trestbps, chol, heartdisease)
# (thalach _|_ exang, age, fbs | restecg, trestbps, sex, chol, heartdisease)
# (thalach _|_ chol, restecg | exang, fbs, age, trestbps, sex, heartdisease)
# (thalach _|_ chol, trestbps | exang, fbs, age, restecg, sex, heartdisease)
# (thalach _|_ trestbps, restecg | exang, fbs, age, sex, chol, heartdisease)
# (thalach _|_ sex | exang, fbs, age, restecg, trestbps, chol)
# (thalach _|_ chol, sex | exang, fbs, age, restecg, trestbps, heartdisease)
# (thalach _|_ sex, restecg | exang, fbs, age, trestbps, chol, heartdisease)
# (thalach _|_ sex, trestbps | exang, fbs, age, restecg, chol, heartdisease)
# (thalach _|_ age | exang, fbs, restecg, trestbps, sex, chol)
# (thalach _|_ age, chol | exang, fbs, restecg, trestbps, sex, heartdisease)
# (thalach _|_ age, restecg | exang, fbs, trestbps, sex, chol, heartdisease)
# (thalach _|_ age, trestbps | exang, fbs, restecg, sex, chol, heartdisease)
# (thalach _|_ age, sex | exang, fbs, restecg, trestbps, chol, heartdisease)
# (thalach _|_ fbs, chol | exang, age, restecg, trestbps, sex, heartdisease)
# (thalach _|_ fbs, restecg | exang, age, trestbps, sex, chol, heartdisease)
# (thalach _|_ fbs, trestbps | exang, age, restecg, sex, chol, heartdisease)
# (thalach _|_ fbs, sex | exang, age, restecg, trestbps, chol, heartdisease)
# (thalach _|_ fbs, age | exang, restecg, trestbps, sex, chol, heartdisease)
# (thalach _|_ exang | fbs, age, restecg, trestbps, sex, chol)
# (thalach _|_ exang, chol | fbs, age, restecg, trestbps, sex, heartdisease)
# (thalach _|_ exang, restecg | fbs, age, trestbps, sex, chol, heartdisease)
# (thalach _|_ exang, trestbps | fbs, age, restecg, sex, chol, heartdisease)
# (thalach _|_ exang, sex | fbs, age, restecg, trestbps, chol, heartdisease)
# (thalach _|_ exang, age | fbs, restecg, trestbps, sex, chol, heartdisease)
# (thalach _|_ exang, fbs | age, restecg, trestbps, sex, chol, heartdisease)
# (thalach _|_ chol | exang, fbs, age, trestbps, sex, restecg, heartdisease)
# (thalach _|_ restecg | exang, fbs, age, trestbps, sex, chol, heartdisease)
# (thalach _|_ trestbps | exang, fbs, age, restecg, sex, chol, heartdisease)
# (thalach _|_ sex | exang, fbs, age, restecg, trestbps, chol, heartdisease)
# (thalach _|_ age | exang, fbs, restecg, trestbps, sex, chol, heartdisease)
# (thalach _|_ fbs | exang, age, restecg, trestbps, sex, chol, heartdisease)
# (thalach _|_ exang | fbs, age, restecg, trestbps, sex, chol, heartdisease)
# (chol _|_ exang, restecg, trestbps, fbs, age, thalach, sex | heartdisease)
# (chol _|_ restecg, trestbps, fbs, age, thalach, sex | exang, heartdisease)
# (chol _|_ exang, age, sex | fbs, trestbps)
# (chol _|_ exang, restecg, trestbps, age, thalach, sex | fbs, heartdisease)
# (chol _|_ exang, sex | age, trestbps)
# (chol _|_ exang, restecg, trestbps, fbs, thalach, sex | heartdisease, age)
# (chol _|_ exang, restecg, trestbps, fbs, age, sex | heartdisease, thalach)
# (chol _|_ exang, restecg, fbs, age, thalach, trestbps | heartdisease, sex)
# (chol _|_ exang, restecg, fbs, age, thalach, sex | heartdisease, trestbps)
# (chol _|_ exang, trestbps, fbs, age, thalach, sex | heartdisease, restecg)
# (chol _|_ age, sex | exang, fbs, trestbps)
# (chol _|_ restecg, trestbps, age, thalach, sex | exang, heartdisease, fbs)
# (chol _|_ sex | exang, age, trestbps)
# (chol _|_ restecg, trestbps, fbs, thalach, sex | exang, age, heartdisease)
# (chol _|_ restecg, sex, fbs, age, trestbps | exang, heartdisease, thalach)
# (chol _|_ restecg, fbs, age, thalach, trestbps | exang, heartdisease, sex)
# (chol _|_ restecg, fbs, age, thalach, sex | exang, heartdisease, trestbps)
# (chol _|_ trestbps, fbs, age, thalach, sex | exang, heartdisease, restecg)
# (chol _|_ exang, sex | fbs, age, trestbps)
# (chol _|_ exang, restecg, trestbps, thalach, sex | fbs, age, heartdisease)
# (chol _|_ exang, age, sex | fbs, thalach, trestbps)
# (chol _|_ exang, restecg, sex, age, trestbps | fbs, heartdisease, thalach)
# (chol _|_ exang, age | fbs, trestbps, sex)
# (chol _|_ exang, restecg, age, thalach, trestbps | fbs, heartdisease, sex)
# (chol _|_ exang, age, sex | fbs, restecg, trestbps)
# (chol _|_ exang, restecg, age, thalach, sex | fbs, heartdisease, trestbps)
# (chol _|_ exang, trestbps, age, thalach, sex | fbs, heartdisease, restecg)
# (chol _|_ exang, sex | age, thalach, trestbps)
# (chol _|_ exang, restecg, trestbps, fbs, sex | heartdisease, age, thalach)
# (chol _|_ exang | age, trestbps, sex)
# (chol _|_ exang, restecg, fbs, thalach, trestbps | heartdisease, age, sex)
# (chol _|_ exang, sex | restecg, age, trestbps)
# (chol _|_ exang, restecg, fbs, thalach, sex | heartdisease, age, trestbps)
# (chol _|_ exang, trestbps, fbs, thalach, sex | heartdisease, age, restecg)
# (chol _|_ exang, restecg, fbs, age, trestbps | heartdisease, thalach, sex)
# (chol _|_ exang, restecg, fbs, age, sex | heartdisease, thalach, trestbps)
# (chol _|_ exang, trestbps, fbs, age, sex | heartdisease, thalach, restecg)
# (chol _|_ exang, fbs, age, thalach, restecg | heartdisease, trestbps, sex)
# (chol _|_ exang, fbs, age, thalach, trestbps | restecg, heartdisease, sex)
# (chol _|_ exang, fbs, age, thalach, sex | restecg, heartdisease, trestbps)
# (chol _|_ sex | exang, age, fbs, trestbps)
# (chol _|_ sex, thalach, trestbps, restecg | exang, age, heartdisease, fbs)
# (chol _|_ age, sex | exang, fbs, thalach, trestbps)
# (chol _|_ sex, age, trestbps, restecg | exang, heartdisease, fbs, thalach)
# (chol _|_ age | exang, fbs, trestbps, sex)
# (chol _|_ age, thalach, trestbps, restecg | exang, heartdisease, fbs, sex)
# (chol _|_ age, sex | exang, fbs, restecg, trestbps)
# (chol _|_ sex, age, thalach, restecg | exang, heartdisease, fbs, trestbps)
# (chol _|_ sex, age, thalach, trestbps | exang, heartdisease, fbs, restecg)
# (chol _|_ sex | exang, age, thalach, trestbps)
# (chol _|_ fbs, sex, trestbps, restecg | exang, age, heartdisease, thalach)
# (chol _|_ fbs, thalach, trestbps, restecg | exang, age, heartdisease, sex)
# (chol _|_ sex | exang, age, restecg, trestbps)
# (chol _|_ fbs, sex, thalach, restecg | exang, age, heartdisease, trestbps)
# (chol _|_ fbs, sex, thalach, trestbps | exang, age, heartdisease, restecg)
# (chol _|_ fbs, age, trestbps, restecg | exang, heartdisease, thalach, sex)
# (chol _|_ fbs, age, sex, restecg | exang, heartdisease, thalach, trestbps)
# (chol _|_ fbs, age, sex, trestbps | exang, heartdisease, thalach, restecg)
# (chol _|_ fbs, age, thalach, restecg | exang, heartdisease, trestbps, sex)
# (chol _|_ fbs, age, thalach, trestbps | exang, heartdisease, restecg, sex)
# (chol _|_ fbs, age, thalach, sex | exang, heartdisease, restecg, trestbps)
# (chol _|_ exang, sex | fbs, age, thalach, trestbps)
# (chol _|_ exang, sex, trestbps, restecg | fbs, age, heartdisease, thalach)
# (chol _|_ exang | fbs, age, trestbps, sex)
# (chol _|_ exang, thalach, trestbps, restecg | fbs, age, heartdisease, sex)
# (chol _|_ exang, sex | fbs, age, restecg, trestbps)
# (chol _|_ exang, sex, thalach, restecg | fbs, age, heartdisease, trestbps)
# (chol _|_ exang, sex, thalach, trestbps | fbs, age, heartdisease, restecg)
# (chol _|_ exang, age | fbs, thalach, trestbps, sex)
# (chol _|_ exang, age, trestbps, restecg | fbs, heartdisease, thalach, sex)
# (chol _|_ exang, age, sex | fbs, thalach, restecg, trestbps)
# (chol _|_ exang, age, sex, restecg | fbs, heartdisease, thalach, trestbps)
# (chol _|_ exang, age, sex, trestbps | fbs, heartdisease, thalach, restecg)
# (chol _|_ exang, age | fbs, restecg, trestbps, sex)
# (chol _|_ exang, age, thalach, restecg | fbs, heartdisease, trestbps, sex)
# (chol _|_ exang, age, thalach, trestbps | fbs, heartdisease, restecg, sex)
# (chol _|_ exang, age, thalach, sex | fbs, heartdisease, restecg, trestbps)
# (chol _|_ exang | age, thalach, trestbps, sex)
# (chol _|_ exang, fbs, trestbps, restecg | heartdisease, age, thalach, sex)
# (chol _|_ exang, sex | restecg, age, thalach, trestbps)
# (chol _|_ exang, sex, fbs, restecg | heartdisease, age, thalach, trestbps)
# (chol _|_ exang, sex, fbs, trestbps | heartdisease, age, thalach, restecg)
# (chol _|_ exang | restecg, age, trestbps, sex)
# (chol _|_ exang, fbs, thalach, restecg | heartdisease, age, trestbps, sex)
# (chol _|_ exang, fbs, thalach, trestbps | restecg, age, heartdisease, sex)
# (chol _|_ exang, fbs, thalach, sex | restecg, age, heartdisease, trestbps)
# (chol _|_ exang, age, fbs, restecg | heartdisease, thalach, trestbps, sex)
# (chol _|_ exang, age, fbs, trestbps | restecg, heartdisease, thalach, sex)
# (chol _|_ exang, age, fbs, sex | restecg, heartdisease, thalach, trestbps)
# (chol _|_ exang, age, fbs, thalach | restecg, heartdisease, trestbps, sex)
# (chol _|_ sex | exang, fbs, age, thalach, trestbps)
# (chol _|_ sex, trestbps, restecg | exang, fbs, age, thalach, heartdisease)
# (chol _|_ thalach, trestbps, restecg | exang, fbs, age, sex, heartdisease)
# (chol _|_ sex | exang, fbs, age, restecg, trestbps)
# (chol _|_ sex, thalach, restecg | exang, fbs, age, trestbps, heartdisease)
# (chol _|_ sex, thalach, trestbps | exang, fbs, age, restecg, heartdisease)
# (chol _|_ age | exang, fbs, thalach, trestbps, sex)
# (chol _|_ age, trestbps, restecg | exang, fbs, thalach, sex, heartdisease)
# (chol _|_ age, sex | exang, fbs, thalach, restecg, trestbps)
# (chol _|_ sex, age, restecg | exang, fbs, thalach, trestbps, heartdisease)
# (chol _|_ sex, age, trestbps | exang, fbs, thalach, restecg, heartdisease)
# (chol _|_ age | exang, fbs, restecg, trestbps, sex)
# (chol _|_ age, thalach, restecg | exang, fbs, trestbps, sex, heartdisease)
# (chol _|_ age, thalach, trestbps | exang, fbs, restecg, sex, heartdisease)
# (chol _|_ age, thalach, sex | exang, fbs, restecg, trestbps, heartdisease)
# (chol _|_ fbs, trestbps, restecg | exang, age, thalach, sex, heartdisease)
# (chol _|_ sex | exang, age, thalach, restecg, trestbps)
# (chol _|_ fbs, sex, restecg | exang, age, thalach, trestbps, heartdisease)
# (chol _|_ fbs, sex, trestbps | exang, age, thalach, restecg, heartdisease)
# (chol _|_ fbs, thalach, restecg | exang, age, trestbps, sex, heartdisease)
# (chol _|_ fbs, thalach, trestbps | exang, age, restecg, sex, heartdisease)
# (chol _|_ fbs, thalach, sex | exang, age, restecg, trestbps, heartdisease)
# (chol _|_ fbs, age, restecg | exang, thalach, trestbps, sex, heartdisease)
# (chol _|_ fbs, age, trestbps | exang, thalach, restecg, sex, heartdisease)
# (chol _|_ fbs, age, sex | exang, thalach, restecg, trestbps, heartdisease)
# (chol _|_ fbs, age, thalach | exang, restecg, trestbps, sex, heartdisease)
# (chol _|_ exang | fbs, age, thalach, trestbps, sex)
# (chol _|_ exang, trestbps, restecg | fbs, age, thalach, sex, heartdisease)
# (chol _|_ exang, sex | fbs, age, thalach, restecg, trestbps)
# (chol _|_ exang, sex, restecg | fbs, age, thalach, trestbps, heartdisease)
# (chol _|_ exang, sex, trestbps | fbs, age, thalach, restecg, heartdisease)
# (chol _|_ exang | fbs, age, restecg, trestbps, sex)
# (chol _|_ exang, thalach, restecg | fbs, age, trestbps, sex, heartdisease)
# (chol _|_ exang, thalach, trestbps | fbs, age, restecg, sex, heartdisease)
# (chol _|_ exang, thalach, sex | fbs, age, restecg, trestbps, heartdisease)
# (chol _|_ exang, age | fbs, thalach, restecg, trestbps, sex)
# (chol _|_ exang, age, restecg | fbs, thalach, trestbps, sex, heartdisease)
# (chol _|_ exang, age, trestbps | fbs, thalach, restecg, sex, heartdisease)
# (chol _|_ exang, age, sex | fbs, thalach, restecg, trestbps, heartdisease)
# (chol _|_ exang, age, thalach | fbs, restecg, trestbps, sex, heartdisease)
# (chol _|_ exang | age, thalach, restecg, trestbps, sex)
# (chol _|_ exang, fbs, restecg | age, thalach, trestbps, sex, heartdisease)
# (chol _|_ exang, fbs, trestbps | age, thalach, restecg, sex, heartdisease)
# (chol _|_ exang, fbs, sex | age, thalach, restecg, trestbps, heartdisease)
# (chol _|_ exang, fbs, thalach | age, restecg, trestbps, sex, heartdisease)
# (chol _|_ exang, age, fbs | thalach, restecg, trestbps, sex, heartdisease)
# (chol _|_ trestbps, restecg | exang, fbs, age, thalach, sex, heartdisease)
# (chol _|_ sex | exang, fbs, age, thalach, trestbps, restecg)
# (chol _|_ sex, restecg | exang, fbs, age, thalach, trestbps, heartdisease)
# (chol _|_ sex, trestbps | exang, fbs, age, thalach, restecg, heartdisease)
# (chol _|_ thalach, restecg | exang, fbs, age, trestbps, sex, heartdisease)
# (chol _|_ thalach, trestbps | exang, fbs, age, restecg, sex, heartdisease)
# (chol _|_ thalach, sex | exang, fbs, age, restecg, trestbps, heartdisease)
# (chol _|_ age | exang, fbs, thalach, trestbps, sex, restecg)
# (chol _|_ age, restecg | exang, fbs, thalach, trestbps, sex, heartdisease)
# (chol _|_ age, trestbps | exang, fbs, thalach, restecg, sex, heartdisease)
# (chol _|_ age, sex | exang, fbs, thalach, restecg, trestbps, heartdisease)
# (chol _|_ age, thalach | exang, fbs, restecg, trestbps, sex, heartdisease)
# (chol _|_ fbs, restecg | exang, age, thalach, trestbps, sex, heartdisease)
# (chol _|_ fbs, trestbps | exang, age, thalach, restecg, sex, heartdisease)
# (chol _|_ fbs, sex | exang, age, thalach, restecg, trestbps, heartdisease)
# (chol _|_ fbs, thalach | exang, age, restecg, trestbps, sex, heartdisease)
# (chol _|_ fbs, age | exang, thalach, restecg, trestbps, sex, heartdisease)
# (chol _|_ exang | fbs, age, thalach, trestbps, sex, restecg)
# (chol _|_ exang, restecg | fbs, age, thalach, trestbps, sex, heartdisease)
# (chol _|_ exang, trestbps | fbs, age, thalach, restecg, sex, heartdisease)
# (chol _|_ exang, sex | fbs, age, thalach, restecg, trestbps, heartdisease)
# (chol _|_ exang, thalach | fbs, age, restecg, trestbps, sex, heartdisease)
# (chol _|_ exang, age | fbs, thalach, restecg, trestbps, sex, heartdisease)
# (chol _|_ exang, fbs | age, thalach, restecg, trestbps, sex, heartdisease)
# (chol _|_ restecg | exang, fbs, age, thalach, sex, trestbps, heartdisease)
# (chol _|_ trestbps | exang, fbs, age, thalach, sex, restecg, heartdisease)
# (chol _|_ sex | exang, fbs, age, thalach, trestbps, restecg, heartdisease)
# (chol _|_ thalach | exang, fbs, age, trestbps, sex, restecg, heartdisease)
# (chol _|_ age | exang, fbs, thalach, trestbps, sex, restecg, heartdisease)
# (chol _|_ fbs | exang, age, thalach, trestbps, sex, restecg, heartdisease)
# (chol _|_ exang | fbs, age, thalach, trestbps, sex, restecg, heartdisease)

# %%
HeartDisease_infer = VariableElimination(model)

# %%
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'age': 28})
print(q['heartdisease'])
# Out:
# /home/acerroot/anaconda3/lib/python3.8/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:518: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   warn(
# Finding Elimination Order: : 100%|██████████| 7/7 [00:00<00:00, 7534.03it/s]
# Eliminating: sex: 100%|██████████| 7/7 [00:00<00:00, 628.17it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-dfb29116c623> in <module>
#       1 q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'age': 28})
# ----> 2 print(q['heartdisease'])
#
# TypeError: 'DiscreteFactor' object is not subscriptable

# %%
q = HeartDisease_infer.query(variables=['heartdisease'],evidence={'chol': 100})
print(q['heartdisease'])
