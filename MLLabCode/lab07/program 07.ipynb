# %% [markdown]
# # 7 Bayesian Network using an API
# Write a program to construct aBayesian network considering medical data. Use this model to
# demonstrate the diagnosis of heart patients using standard Heart Disease Data Set. You can use
# Java/Python ML library classes/API.

# %%
import sys
from urllib.request import urlopen
import numpy as np
import pandas as pd

from pgmpy.estimators import MaximumLikelihoodEstimator
from pgmpy.models import BayesianModel

from pgmpy.inference import VariableElimination

# %%
heartDisease_df = pd.read_csv('heartDisease.csv')

# %%
heartDisease_df.drop(['ca', 'slope', 'thal', 'oldpeak'], axis=1, inplace=True)

# %%
heartDisease_df.replace('?', np.nan, inplace=True)

# %%
model = BayesianModel([('age', 'trestbps'),
('age', 'fbs'), ('sex', 'trestbps'),
('exang', 'trestbps'), ('trestbps', 'heartdisease'),
('fbs', 'heartdisease'), ('heartdisease', 'restecg'),
('heartdisease', 'thalach'), ('heartdisease', 'chol')])
# Learing CPDs using Maximum Likelihood Estimators
model.fit(heartDisease_df, estimator=MaximumLikelihoodEstimator)

# %%
print(model.get_cpds('age'))
print(model.get_cpds('chol'))
print(model.get_cpds('sex'))
model.get_independencies()
# Out:
# +---------+------------+
# | age(29) | 0.00330033 |
# +---------+------------+
# | age(34) | 0.00660066 |
# +---------+------------+
# | age(35) | 0.0132013  |
# +---------+------------+
# | age(37) | 0.00660066 |
# +---------+------------+
# | age(38) | 0.00990099 |
# +---------+------------+
# | age(39) | 0.0132013  |
# +---------+------------+
# | age(40) | 0.00990099 |
# +---------+------------+
# | age(41) | 0.0330033  |
# +---------+------------+
# | age(42) | 0.0264026  |
# +---------+------------+
# | age(43) | 0.0264026  |
# +---------+------------+
# | age(44) | 0.0363036  |
# +---------+------------+
# | age(45) | 0.0264026  |
# +---------+------------+
# | age(46) | 0.0231023  |
# +---------+------------+
# | age(47) | 0.0165017  |
# +---------+------------+
# | age(48) | 0.0231023  |
# +---------+------------+
# | age(49) | 0.0165017  |
# +---------+------------+
# | age(50) | 0.0231023  |
# +---------+------------+
# | age(51) | 0.039604   |
# +---------+------------+
# | age(52) | 0.0429043  |
# +---------+------------+
# | age(53) | 0.0264026  |
# +---------+------------+
# | age(54) | 0.0528053  |
# +---------+------------+
# | age(55) | 0.0264026  |
# +---------+------------+
# | age(56) | 0.0363036  |
# +---------+------------+
# | age(57) | 0.0561056  |
# +---------+------------+
# | age(58) | 0.0627063  |
# +---------+------------+
# | age(59) | 0.0462046  |
# +---------+------------+
# | age(60) | 0.0363036  |
# +---------+------------+
# | age(61) | 0.0264026  |
# +---------+------------+
# | age(62) | 0.0363036  |
# +---------+------------+
# | age(63) | 0.029703   |
# +---------+------------+
# | age(64) | 0.0330033  |
# +---------+------------+
# | age(65) | 0.0264026  |
# +---------+------------+
# | age(66) | 0.0231023  |
# +---------+------------+
# | age(67) | 0.029703   |
# +---------+------------+
# | age(68) | 0.0132013  |
# +---------+------------+
# | age(69) | 0.00990099 |
# +---------+------------+
# | age(70) | 0.0132013  |
# +---------+------------+
# | age(71) | 0.00990099 |
# +---------+------------+
# | age(74) | 0.00330033 |
# +---------+------------+
# | age(76) | 0.00330033 |
# +---------+------------+
# | age(77) | 0.00330033 |
# +---------+------------+
# +--------------+----------------------+----------------------+
# | heartdisease | heartdisease(0)      | heartdisease(1)      |
# +--------------+----------------------+----------------------+
# | chol(126)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(131)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(141)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(149)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(157)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(160)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(164)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(166)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(167)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(168)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(169)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(172)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(174)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(175)    | 0.0                  | 0.01818181818181818  |
# +--------------+----------------------+----------------------+
# | chol(176)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(177)    | 0.014492753623188406 | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(178)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(180)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(182)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(183)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(184)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(185)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(186)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(187)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(188)    | 0.014492753623188406 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(192)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(193)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(195)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(196)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(197)    | 0.014492753623188406 | 0.024242424242424242 |
# +--------------+----------------------+----------------------+
# | chol(198)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(199)    | 0.0                  | 0.01818181818181818  |
# +--------------+----------------------+----------------------+
# | chol(200)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(201)    | 0.0                  | 0.01818181818181818  |
# +--------------+----------------------+----------------------+
# | chol(203)    | 0.014492753623188406 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(204)    | 0.014492753623188406 | 0.024242424242424242 |
# +--------------+----------------------+----------------------+
# | chol(205)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(206)    | 0.014492753623188406 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(207)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(208)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(209)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(210)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(211)    | 0.0                  | 0.024242424242424242 |
# +--------------+----------------------+----------------------+
# | chol(212)    | 0.028985507246376812 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(213)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(214)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(215)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(216)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(217)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(218)    | 0.014492753623188406 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(219)    | 0.007246376811594203 | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(220)    | 0.0                  | 0.01818181818181818  |
# +--------------+----------------------+----------------------+
# | chol(221)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(222)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(223)    | 0.007246376811594203 | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(224)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(225)    | 0.014492753623188406 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(226)    | 0.0                  | 0.024242424242424242 |
# +--------------+----------------------+----------------------+
# | chol(227)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(228)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(229)    | 0.021739130434782608 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(230)    | 0.021739130434782608 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(231)    | 0.014492753623188406 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(232)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(233)    | 0.007246376811594203 | 0.01818181818181818  |
# +--------------+----------------------+----------------------+
# | chol(234)    | 0.014492753623188406 | 0.024242424242424242 |
# +--------------+----------------------+----------------------+
# | chol(235)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(236)    | 0.007246376811594203 | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(237)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(239)    | 0.014492753623188406 | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(240)    | 0.0                  | 0.024242424242424242 |
# +--------------+----------------------+----------------------+
# | chol(241)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(242)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(243)    | 0.014492753623188406 | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(244)    | 0.007246376811594203 | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(245)    | 0.0                  | 0.01818181818181818  |
# +--------------+----------------------+----------------------+
# | chol(246)    | 0.014492753623188406 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(247)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(248)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(249)    | 0.021739130434782608 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(250)    | 0.0                  | 0.01818181818181818  |
# +--------------+----------------------+----------------------+
# | chol(252)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(253)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(254)    | 0.028985507246376812 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(255)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(256)    | 0.014492753623188406 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(257)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(258)    | 0.014492753623188406 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(259)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(260)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(261)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(262)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(263)    | 0.007246376811594203 | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(264)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(265)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(266)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(267)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(268)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(269)    | 0.014492753623188406 | 0.01818181818181818  |
# +--------------+----------------------+----------------------+
# | chol(270)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(271)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(273)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(274)    | 0.021739130434782608 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(275)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(276)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(277)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(278)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(281)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(282)    | 0.028985507246376812 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(283)    | 0.014492753623188406 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(284)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(286)    | 0.014492753623188406 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(288)    | 0.014492753623188406 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(289)    | 0.014492753623188406 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(290)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(293)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(294)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(295)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(298)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(299)    | 0.014492753623188406 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(300)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(302)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(303)    | 0.0                  | 0.01818181818181818  |
# +--------------+----------------------+----------------------+
# | chol(304)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(305)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(306)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(307)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(308)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(309)    | 0.014492753623188406 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(311)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(313)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(315)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(318)    | 0.007246376811594203 | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(319)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(321)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(322)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(325)    | 0.0                  | 0.012121212121212121 |
# +--------------+----------------------+----------------------+
# | chol(326)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(327)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(330)    | 0.014492753623188406 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(335)    | 0.014492753623188406 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(340)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(341)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(342)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(353)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(354)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(360)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(394)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(407)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(409)    | 0.007246376811594203 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(417)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# | chol(564)    | 0.0                  | 0.006060606060606061 |
# +--------------+----------------------+----------------------+
# +--------+----------+
# | sex(0) | 0.316832 |
# +--------+----------+
# | sex(1) | 0.683168 |
# +--------+----------+
# (age _|_ exang, sex)
# (age _|_ exang, sex | fbs)
# (age _|_ chol, thalach, restecg | heartdisease)
# (age _|_ sex | exang)
# (age _|_ exang | sex)
# (age _|_ chol, thalach, restecg | fbs, heartdisease)
# (age _|_ sex | fbs, exang)
# (age _|_ exang | fbs, sex)
# (age _|_ chol, thalach, restecg, heartdisease | fbs, trestbps)
# (age _|_ chol, thalach, restecg | exang, heartdisease)
# (age _|_ chol, thalach, restecg | sex, heartdisease)
# (age _|_ thalach, restecg | chol, heartdisease)
# (age _|_ chol, thalach | restecg, heartdisease)
# (age _|_ chol, thalach, restecg | trestbps, heartdisease)
# (age _|_ chol, restecg | thalach, heartdisease)
# (age _|_ chol, thalach, restecg | fbs, exang, heartdisease)
# (age _|_ chol, thalach, restecg | fbs, sex, heartdisease)
# (age _|_ thalach, restecg | fbs, chol, heartdisease)
# (age _|_ chol, thalach | fbs, restecg, heartdisease)
# (age _|_ chol, thalach, restecg | fbs, trestbps, heartdisease)
# (age _|_ chol, restecg | fbs, thalach, heartdisease)
# (age _|_ chol, thalach, restecg, heartdisease | fbs, exang, trestbps)
# (age _|_ chol, thalach, restecg, heartdisease | fbs, trestbps, sex)
# (age _|_ thalach, restecg, heartdisease | fbs, chol, trestbps)
# (age _|_ chol, thalach, heartdisease | fbs, trestbps, restecg)
# (age _|_ chol, restecg, heartdisease | fbs, trestbps, thalach)
# (age _|_ chol, thalach, restecg | exang, sex, heartdisease)
# (age _|_ thalach, restecg | exang, chol, heartdisease)
# (age _|_ chol, thalach | exang, restecg, heartdisease)
# (age _|_ chol, thalach, restecg | exang, trestbps, heartdisease)
# (age _|_ chol, restecg | exang, thalach, heartdisease)
# (age _|_ thalach, restecg | chol, sex, heartdisease)
# (age _|_ chol, thalach | sex, restecg, heartdisease)
# (age _|_ chol, thalach, restecg | trestbps, sex, heartdisease)
# (age _|_ chol, restecg | thalach, sex, heartdisease)
# (age _|_ thalach | chol, restecg, heartdisease)
# (age _|_ thalach, restecg | chol, trestbps, heartdisease)
# (age _|_ restecg | chol, thalach, heartdisease)
# (age _|_ chol, thalach | trestbps, restecg, heartdisease)
# (age _|_ chol | thalach, restecg, heartdisease)
# (age _|_ chol, restecg | trestbps, thalach, heartdisease)
# (age _|_ chol, thalach, restecg | fbs, exang, sex, heartdisease)
# (age _|_ thalach, restecg | fbs, exang, chol, heartdisease)
# (age _|_ chol, thalach | fbs, exang, restecg, heartdisease)
# (age _|_ chol, thalach, restecg | fbs, exang, trestbps, heartdisease)
# (age _|_ chol, restecg | fbs, exang, thalach, heartdisease)
# (age _|_ thalach, restecg | fbs, chol, sex, heartdisease)
# (age _|_ chol, thalach | fbs, sex, restecg, heartdisease)
# (age _|_ chol, thalach, restecg | fbs, trestbps, sex, heartdisease)
# (age _|_ chol, restecg | fbs, thalach, sex, heartdisease)
# (age _|_ thalach | fbs, chol, restecg, heartdisease)
# (age _|_ thalach, restecg | fbs, chol, trestbps, heartdisease)
# (age _|_ restecg | fbs, chol, thalach, heartdisease)
# (age _|_ chol, thalach | fbs, trestbps, restecg, heartdisease)
# (age _|_ chol | fbs, thalach, restecg, heartdisease)
# (age _|_ chol, restecg | fbs, trestbps, thalach, heartdisease)
# (age _|_ chol, thalach, restecg, heartdisease | fbs, exang, sex, trestbps)
# (age _|_ thalach, restecg, heartdisease | fbs, exang, chol, trestbps)
# (age _|_ chol, thalach, heartdisease | fbs, exang, trestbps, restecg)
# (age _|_ chol, restecg, heartdisease | fbs, exang, thalach, trestbps)
# (age _|_ thalach, restecg, heartdisease | fbs, chol, sex, trestbps)
# (age _|_ chol, thalach, heartdisease | fbs, trestbps, sex, restecg)
# (age _|_ chol, restecg, heartdisease | fbs, trestbps, sex, thalach)
# (age _|_ thalach, heartdisease | fbs, chol, trestbps, restecg)
# (age _|_ restecg, heartdisease | fbs, chol, thalach, trestbps)
# (age _|_ chol, heartdisease | fbs, trestbps, thalach, restecg)
# (age _|_ thalach, restecg | exang, sex, chol, heartdisease)
# (age _|_ chol, thalach | exang, sex, restecg, heartdisease)
# (age _|_ chol, thalach, restecg | exang, sex, trestbps, heartdisease)
# (age _|_ chol, restecg | exang, sex, thalach, heartdisease)
# (age _|_ thalach | exang, chol, restecg, heartdisease)
# (age _|_ thalach, restecg | exang, chol, trestbps, heartdisease)
# (age _|_ restecg | exang, thalach, chol, heartdisease)
# (age _|_ chol, thalach | exang, trestbps, restecg, heartdisease)
# (age _|_ chol | exang, thalach, restecg, heartdisease)
# (age _|_ chol, restecg | exang, thalach, trestbps, heartdisease)
# (age _|_ thalach | chol, sex, restecg, heartdisease)
# (age _|_ thalach, restecg | chol, sex, trestbps, heartdisease)
# (age _|_ restecg | chol, sex, thalach, heartdisease)
# (age _|_ chol, thalach | trestbps, sex, restecg, heartdisease)
# (age _|_ chol | thalach, sex, restecg, heartdisease)
# (age _|_ chol, restecg | trestbps, sex, thalach, heartdisease)
# (age _|_ thalach | chol, trestbps, restecg, heartdisease)
# (age _|_ restecg | chol, thalach, trestbps, heartdisease)
# (age _|_ chol | trestbps, thalach, restecg, heartdisease)
# (age _|_ thalach, restecg | fbs, heartdisease, exang, sex, chol)
# (age _|_ chol, thalach | fbs, heartdisease, exang, sex, restecg)
# (age _|_ chol, thalach, restecg | fbs, heartdisease, exang, sex, trestbps)
# (age _|_ chol, restecg | fbs, heartdisease, exang, sex, thalach)
# (age _|_ thalach | fbs, heartdisease, exang, chol, restecg)
# (age _|_ thalach, restecg | fbs, heartdisease, exang, chol, trestbps)
# (age _|_ restecg | fbs, heartdisease, exang, chol, thalach)
# (age _|_ chol, thalach | fbs, heartdisease, exang, restecg, trestbps)
# (age _|_ chol | fbs, heartdisease, exang, restecg, thalach)
# (age _|_ chol, restecg | fbs, heartdisease, exang, trestbps, thalach)
# (age _|_ thalach | fbs, heartdisease, chol, sex, restecg)
# (age _|_ thalach, restecg | fbs, heartdisease, chol, sex, trestbps)
# (age _|_ restecg | fbs, heartdisease, chol, sex, thalach)
# (age _|_ chol, thalach | fbs, heartdisease, sex, restecg, trestbps)
# (age _|_ chol | fbs, heartdisease, sex, restecg, thalach)
# (age _|_ chol, restecg | fbs, heartdisease, sex, trestbps, thalach)
# (age _|_ thalach | fbs, heartdisease, chol, restecg, trestbps)
# (age _|_ restecg | fbs, heartdisease, chol, trestbps, thalach)
# (age _|_ chol | fbs, heartdisease, restecg, trestbps, thalach)
# (age _|_ thalach, restecg, heartdisease | fbs, exang, sex, chol, trestbps)
# (age _|_ chol, thalach, heartdisease | fbs, exang, sex, restecg, trestbps)
# (age _|_ chol, restecg, heartdisease | fbs, exang, sex, trestbps, thalach)
# (age _|_ thalach, heartdisease | fbs, exang, chol, restecg, trestbps)
# (age _|_ restecg, heartdisease | fbs, exang, chol, trestbps, thalach)
# (age _|_ chol, heartdisease | fbs, exang, restecg, trestbps, thalach)
# (age _|_ thalach, heartdisease | fbs, chol, sex, restecg, trestbps)
# (age _|_ restecg, heartdisease | fbs, chol, sex, trestbps, thalach)
# (age _|_ chol, heartdisease | fbs, sex, restecg, trestbps, thalach)
# (age _|_ heartdisease | fbs, chol, restecg, trestbps, thalach)
# (age _|_ thalach | heartdisease, exang, sex, chol, restecg)
# (age _|_ thalach, restecg | heartdisease, exang, sex, chol, trestbps)
# (age _|_ restecg | heartdisease, exang, sex, chol, thalach)
# (age _|_ chol, thalach | heartdisease, exang, sex, restecg, trestbps)
# (age _|_ chol | heartdisease, exang, sex, restecg, thalach)
# (age _|_ chol, restecg | heartdisease, exang, sex, trestbps, thalach)
# (age _|_ thalach | heartdisease, exang, chol, restecg, trestbps)
# (age _|_ restecg | heartdisease, exang, chol, trestbps, thalach)
# (age _|_ chol | heartdisease, exang, restecg, trestbps, thalach)
# (age _|_ thalach | heartdisease, chol, sex, restecg, trestbps)
# (age _|_ restecg | heartdisease, chol, sex, trestbps, thalach)
# (age _|_ chol | heartdisease, sex, restecg, trestbps, thalach)
# (age _|_ thalach | fbs, heartdisease, exang, sex, chol, restecg)
# (age _|_ thalach, restecg | fbs, heartdisease, exang, sex, chol, trestbps)
# (age _|_ restecg | fbs, heartdisease, exang, sex, chol, thalach)
# (age _|_ chol, thalach | fbs, heartdisease, exang, sex, restecg, trestbps)
# (age _|_ chol | fbs, heartdisease, exang, sex, restecg, thalach)
# (age _|_ chol, restecg | fbs, heartdisease, exang, sex, trestbps, thalach)
# (age _|_ thalach | fbs, heartdisease, exang, chol, restecg, trestbps)
# (age _|_ restecg | fbs, heartdisease, exang, chol, trestbps, thalach)
# (age _|_ chol | fbs, heartdisease, exang, restecg, trestbps, thalach)
# (age _|_ thalach | fbs, heartdisease, chol, sex, restecg, trestbps)
# (age _|_ restecg | fbs, heartdisease, chol, sex, trestbps, thalach)
# (age _|_ chol | fbs, heartdisease, sex, restecg, trestbps, thalach)
# (age _|_ thalach, heartdisease | fbs, exang, sex, chol, restecg, trestbps)
# (age _|_ restecg, heartdisease | fbs, exang, sex, chol, trestbps, thalach)
# (age _|_ chol, heartdisease | fbs, exang, sex, restecg, trestbps, thalach)
# (age _|_ heartdisease | fbs, exang, chol, restecg, trestbps, thalach)
# (age _|_ heartdisease | fbs, chol, sex, restecg, trestbps, thalach)
# (age _|_ thalach | heartdisease, exang, sex, chol, restecg, trestbps)
# (age _|_ restecg | heartdisease, exang, sex, chol, trestbps, thalach)
# (age _|_ chol | heartdisease, exang, sex, restecg, trestbps, thalach)
# (age _|_ thalach | fbs, heartdisease, exang, sex, chol, restecg, trestbps)
# (age _|_ restecg | fbs, heartdisease, exang, sex, chol, trestbps, thalach)
# (age _|_ chol | fbs, heartdisease, exang, sex, restecg, trestbps, thalach)
# (age _|_ heartdisease | fbs, exang, sex, chol, restecg, trestbps, thalach)
# (trestbps _|_ chol, thalach, restecg | heartdisease)
# (trestbps _|_ fbs | age)
# (trestbps _|_ chol, thalach, restecg | fbs, heartdisease)
# (trestbps _|_ chol, thalach, restecg | exang, heartdisease)
# (trestbps _|_ chol, thalach, restecg | sex, heartdisease)
# (trestbps _|_ thalach, restecg | chol, heartdisease)
# (trestbps _|_ chol, thalach | restecg, heartdisease)
# (trestbps _|_ chol, restecg | thalach, heartdisease)
# (trestbps _|_ chol, thalach, restecg | age, heartdisease)
# (trestbps _|_ fbs | exang, age)
# (trestbps _|_ fbs | sex, age)
# (trestbps _|_ chol, thalach, restecg | fbs, exang, heartdisease)
# (trestbps _|_ chol, thalach, restecg | fbs, sex, heartdisease)
# (trestbps _|_ thalach, restecg | fbs, chol, heartdisease)
# (trestbps _|_ chol, thalach | fbs, restecg, heartdisease)
# (trestbps _|_ chol, restecg | fbs, thalach, heartdisease)
# (trestbps _|_ chol, thalach, restecg | fbs, age, heartdisease)
# (trestbps _|_ chol, thalach, restecg | exang, sex, heartdisease)
# (trestbps _|_ thalach, restecg | exang, chol, heartdisease)
# (trestbps _|_ chol, thalach | exang, restecg, heartdisease)
# (trestbps _|_ chol, restecg | exang, thalach, heartdisease)
# (trestbps _|_ chol, thalach, restecg | exang, age, heartdisease)
# (trestbps _|_ thalach, restecg | chol, sex, heartdisease)
# (trestbps _|_ chol, thalach | sex, restecg, heartdisease)
# (trestbps _|_ chol, restecg | thalach, sex, heartdisease)
# (trestbps _|_ chol, thalach, restecg | sex, age, heartdisease)
# (trestbps _|_ thalach | chol, restecg, heartdisease)
# (trestbps _|_ restecg | chol, thalach, heartdisease)
# (trestbps _|_ thalach, restecg | chol, age, heartdisease)
# (trestbps _|_ chol | thalach, restecg, heartdisease)
# (trestbps _|_ chol, thalach | age, restecg, heartdisease)
# (trestbps _|_ chol, restecg | thalach, age, heartdisease)
# (trestbps _|_ fbs | exang, sex, age)
# (trestbps _|_ chol, thalach, restecg | fbs, exang, sex, heartdisease)
# (trestbps _|_ thalach, restecg | fbs, exang, chol, heartdisease)
# (trestbps _|_ chol, thalach | fbs, exang, restecg, heartdisease)
# (trestbps _|_ chol, restecg | fbs, exang, thalach, heartdisease)
# (trestbps _|_ chol, thalach, restecg | fbs, exang, age, heartdisease)
# (trestbps _|_ thalach, restecg | fbs, chol, sex, heartdisease)
# (trestbps _|_ chol, thalach | fbs, sex, restecg, heartdisease)
# (trestbps _|_ chol, restecg | fbs, thalach, sex, heartdisease)
# (trestbps _|_ chol, thalach, restecg | fbs, sex, age, heartdisease)
# (trestbps _|_ thalach | fbs, chol, restecg, heartdisease)
# (trestbps _|_ restecg | fbs, chol, thalach, heartdisease)
# (trestbps _|_ thalach, restecg | fbs, chol, age, heartdisease)
# (trestbps _|_ chol | fbs, thalach, restecg, heartdisease)
# (trestbps _|_ chol, thalach | age, fbs, restecg, heartdisease)
# (trestbps _|_ chol, restecg | fbs, thalach, age, heartdisease)
# (trestbps _|_ thalach, restecg | exang, sex, chol, heartdisease)
# (trestbps _|_ chol, thalach | exang, sex, restecg, heartdisease)
# (trestbps _|_ chol, restecg | exang, sex, thalach, heartdisease)
# (trestbps _|_ chol, thalach, restecg | exang, sex, age, heartdisease)
# (trestbps _|_ thalach | exang, chol, restecg, heartdisease)
# (trestbps _|_ restecg | exang, thalach, chol, heartdisease)
# (trestbps _|_ thalach, restecg | exang, chol, age, heartdisease)
# (trestbps _|_ chol | exang, thalach, restecg, heartdisease)
# (trestbps _|_ chol, thalach | age, exang, restecg, heartdisease)
# (trestbps _|_ chol, restecg | exang, thalach, age, heartdisease)
# (trestbps _|_ thalach | chol, sex, restecg, heartdisease)
# (trestbps _|_ restecg | chol, sex, thalach, heartdisease)
# (trestbps _|_ thalach, restecg | chol, sex, age, heartdisease)
# (trestbps _|_ chol | thalach, sex, restecg, heartdisease)
# (trestbps _|_ chol, thalach | age, sex, restecg, heartdisease)
# (trestbps _|_ chol, restecg | thalach, sex, age, heartdisease)
# (trestbps _|_ thalach | age, chol, restecg, heartdisease)
# (trestbps _|_ restecg | chol, thalach, age, heartdisease)
# (trestbps _|_ chol | age, thalach, restecg, heartdisease)
# (trestbps _|_ thalach, restecg | fbs, heartdisease, exang, sex, chol)
# (trestbps _|_ chol, thalach | fbs, heartdisease, exang, sex, restecg)
# (trestbps _|_ chol, restecg | fbs, heartdisease, exang, sex, thalach)
# (trestbps _|_ chol, thalach, restecg | fbs, heartdisease, exang, sex, age)
# (trestbps _|_ thalach | fbs, heartdisease, exang, chol, restecg)
# (trestbps _|_ restecg | fbs, heartdisease, exang, chol, thalach)
# (trestbps _|_ thalach, restecg | fbs, heartdisease, exang, chol, age)
# (trestbps _|_ chol | fbs, heartdisease, exang, restecg, thalach)
# (trestbps _|_ chol, thalach | fbs, heartdisease, exang, restecg, age)
# (trestbps _|_ chol, restecg | fbs, heartdisease, exang, thalach, age)
# (trestbps _|_ thalach | fbs, heartdisease, chol, sex, restecg)
# (trestbps _|_ restecg | fbs, heartdisease, chol, sex, thalach)
# (trestbps _|_ thalach, restecg | fbs, heartdisease, chol, sex, age)
# (trestbps _|_ chol | fbs, heartdisease, sex, restecg, thalach)
# (trestbps _|_ chol, thalach | fbs, heartdisease, sex, restecg, age)
# (trestbps _|_ chol, restecg | fbs, heartdisease, sex, thalach, age)
# (trestbps _|_ thalach | fbs, heartdisease, chol, restecg, age)
# (trestbps _|_ restecg | fbs, heartdisease, chol, thalach, age)
# (trestbps _|_ chol | fbs, heartdisease, restecg, thalach, age)
# (trestbps _|_ thalach | heartdisease, exang, sex, chol, restecg)
# (trestbps _|_ restecg | heartdisease, exang, sex, chol, thalach)
# (trestbps _|_ thalach, restecg | heartdisease, exang, sex, chol, age)
# (trestbps _|_ chol | heartdisease, exang, sex, restecg, thalach)
# (trestbps _|_ chol, thalach | heartdisease, exang, sex, restecg, age)
# (trestbps _|_ chol, restecg | heartdisease, exang, sex, thalach, age)
# (trestbps _|_ thalach | heartdisease, exang, chol, restecg, age)
# (trestbps _|_ restecg | heartdisease, exang, chol, thalach, age)
# (trestbps _|_ chol | heartdisease, exang, restecg, thalach, age)
# (trestbps _|_ thalach | heartdisease, chol, sex, restecg, age)
# (trestbps _|_ restecg | heartdisease, chol, sex, thalach, age)
# (trestbps _|_ chol | heartdisease, sex, restecg, thalach, age)
# (trestbps _|_ thalach | fbs, heartdisease, exang, sex, chol, restecg)
# (trestbps _|_ restecg | fbs, heartdisease, exang, sex, chol, thalach)
# (trestbps _|_ thalach, restecg | fbs, heartdisease, exang, sex, chol, age)
# (trestbps _|_ chol | fbs, heartdisease, exang, sex, restecg, thalach)
# (trestbps _|_ chol, thalach | fbs, heartdisease, exang, sex, restecg, age)
# (trestbps _|_ chol, restecg | fbs, heartdisease, exang, sex, thalach, age)
# (trestbps _|_ thalach | fbs, heartdisease, exang, chol, restecg, age)
# (trestbps _|_ restecg | fbs, heartdisease, exang, chol, thalach, age)
# (trestbps _|_ chol | fbs, heartdisease, exang, restecg, thalach, age)
# (trestbps _|_ thalach | fbs, heartdisease, chol, sex, restecg, age)
# (trestbps _|_ restecg | fbs, heartdisease, chol, sex, thalach, age)
# (trestbps _|_ chol | fbs, heartdisease, sex, restecg, thalach, age)
# (trestbps _|_ thalach | heartdisease, exang, sex, chol, restecg, age)
# (trestbps _|_ restecg | heartdisease, exang, sex, chol, thalach, age)
# (trestbps _|_ chol | heartdisease, exang, sex, restecg, thalach, age)
# (trestbps _|_ thalach | fbs, heartdisease, exang, sex, chol, restecg, age)
# (trestbps _|_ restecg | fbs, heartdisease, exang, sex, chol, thalach, age)
# (trestbps _|_ chol | fbs, heartdisease, exang, sex, restecg, thalach, age)
# (fbs _|_ exang, sex)
# (fbs _|_ chol, thalach, restecg | heartdisease)
# (fbs _|_ sex | exang)
# (fbs _|_ exang | sex)
# (fbs _|_ exang, sex, trestbps | age)
# (fbs _|_ chol, thalach, restecg | exang, heartdisease)
# (fbs _|_ chol, thalach, restecg | sex, heartdisease)
# (fbs _|_ thalach, restecg | chol, heartdisease)
# (fbs _|_ chol, thalach | restecg, heartdisease)
# (fbs _|_ chol, thalach, restecg | trestbps, heartdisease)
# (fbs _|_ chol, restecg | thalach, heartdisease)
# (fbs _|_ chol, thalach, restecg | age, heartdisease)
# (fbs _|_ trestbps, sex | exang, age)
# (fbs _|_ exang, trestbps | sex, age)
# (fbs _|_ exang, sex | trestbps, age)
# (fbs _|_ chol, thalach, restecg | exang, sex, heartdisease)
# (fbs _|_ thalach, restecg | exang, chol, heartdisease)
# (fbs _|_ chol, thalach | exang, restecg, heartdisease)
# (fbs _|_ chol, thalach, restecg | exang, trestbps, heartdisease)
# (fbs _|_ chol, restecg | exang, thalach, heartdisease)
# (fbs _|_ chol, thalach, restecg | exang, age, heartdisease)
# (fbs _|_ thalach, restecg | chol, sex, heartdisease)
# (fbs _|_ chol, thalach | sex, restecg, heartdisease)
# (fbs _|_ chol, thalach, restecg | trestbps, sex, heartdisease)
# (fbs _|_ chol, restecg | thalach, sex, heartdisease)
# (fbs _|_ chol, thalach, restecg | sex, age, heartdisease)
# (fbs _|_ thalach | chol, restecg, heartdisease)
# (fbs _|_ thalach, restecg | chol, trestbps, heartdisease)
# (fbs _|_ restecg | chol, thalach, heartdisease)
# (fbs _|_ thalach, restecg | chol, age, heartdisease)
# (fbs _|_ chol, thalach | trestbps, restecg, heartdisease)
# (fbs _|_ chol | thalach, restecg, heartdisease)
# (fbs _|_ chol, thalach | age, restecg, heartdisease)
# (fbs _|_ chol, restecg | trestbps, thalach, heartdisease)
# (fbs _|_ chol, restecg, thalach, exang, sex | trestbps, age, heartdisease)
# (fbs _|_ chol, restecg | thalach, age, heartdisease)
# (fbs _|_ trestbps | exang, sex, age)
# (fbs _|_ sex | exang, trestbps, age)
# (fbs _|_ exang | trestbps, sex, age)
# (fbs _|_ exang, sex | chol, trestbps, age)
# (fbs _|_ exang, sex | age, trestbps, restecg)
# (fbs _|_ exang, sex | trestbps, thalach, age)
# (fbs _|_ thalach, restecg | exang, sex, chol, heartdisease)
# (fbs _|_ chol, thalach | exang, sex, restecg, heartdisease)
# (fbs _|_ chol, thalach, restecg | exang, sex, trestbps, heartdisease)
# (fbs _|_ chol, restecg | exang, sex, thalach, heartdisease)
# (fbs _|_ chol, thalach, restecg | exang, sex, age, heartdisease)
# (fbs _|_ thalach | exang, chol, restecg, heartdisease)
# (fbs _|_ thalach, restecg | exang, chol, trestbps, heartdisease)
# (fbs _|_ restecg | exang, thalach, chol, heartdisease)
# (fbs _|_ thalach, restecg | exang, chol, age, heartdisease)
# (fbs _|_ chol, thalach | exang, trestbps, restecg, heartdisease)
# (fbs _|_ chol | exang, thalach, restecg, heartdisease)
# (fbs _|_ chol, thalach | age, exang, restecg, heartdisease)
# (fbs _|_ chol, restecg | exang, thalach, trestbps, heartdisease)
# (fbs _|_ chol, sex, restecg, thalach | exang, trestbps, age, heartdisease)
# (fbs _|_ chol, restecg | exang, thalach, age, heartdisease)
# (fbs _|_ thalach | chol, sex, restecg, heartdisease)
# (fbs _|_ thalach, restecg | chol, sex, trestbps, heartdisease)
# (fbs _|_ restecg | chol, sex, thalach, heartdisease)
# (fbs _|_ thalach, restecg | chol, sex, age, heartdisease)
# (fbs _|_ chol, thalach | trestbps, sex, restecg, heartdisease)
# (fbs _|_ chol | thalach, sex, restecg, heartdisease)
# (fbs _|_ chol, thalach | age, sex, restecg, heartdisease)
# (fbs _|_ chol, restecg | trestbps, sex, thalach, heartdisease)
# (fbs _|_ exang, thalach, chol, restecg | trestbps, sex, age, heartdisease)
# (fbs _|_ chol, restecg | thalach, sex, age, heartdisease)
# (fbs _|_ thalach | chol, trestbps, restecg, heartdisease)
# (fbs _|_ thalach | age, chol, restecg, heartdisease)
# (fbs _|_ restecg | chol, thalach, trestbps, heartdisease)
# (fbs _|_ exang, sex, restecg, thalach | chol, trestbps, age, heartdisease)
# (fbs _|_ restecg | chol, thalach, age, heartdisease)
# (fbs _|_ chol | trestbps, thalach, restecg, heartdisease)
# (fbs _|_ exang, sex, chol, thalach | age, trestbps, restecg, heartdisease)
# (fbs _|_ chol | age, thalach, restecg, heartdisease)
# (fbs _|_ exang, sex, chol, restecg | trestbps, thalach, age, heartdisease)
# (fbs _|_ sex | exang, chol, trestbps, age)
# (fbs _|_ sex | age, exang, trestbps, restecg)
# (fbs _|_ sex | exang, thalach, trestbps, age)
# (fbs _|_ exang | chol, sex, trestbps, age)
# (fbs _|_ exang | age, trestbps, sex, restecg)
# (fbs _|_ exang | trestbps, sex, age, thalach)
# (fbs _|_ exang, sex | age, chol, trestbps, restecg)
# (fbs _|_ exang, sex | chol, thalach, trestbps, age)
# (fbs _|_ exang, sex | age, trestbps, thalach, restecg)
# (fbs _|_ thalach | heartdisease, exang, sex, chol, restecg)
# (fbs _|_ thalach, restecg | heartdisease, exang, sex, chol, trestbps)
# (fbs _|_ restecg | heartdisease, exang, sex, chol, thalach)
# (fbs _|_ thalach, restecg | heartdisease, exang, sex, chol, age)
# (fbs _|_ chol, thalach | heartdisease, exang, sex, restecg, trestbps)
# (fbs _|_ chol | heartdisease, exang, sex, restecg, thalach)
# (fbs _|_ chol, thalach | heartdisease, exang, sex, restecg, age)
# (fbs _|_ chol, restecg | heartdisease, exang, sex, trestbps, thalach)
# (fbs _|_ chol, thalach, restecg | heartdisease, exang, sex, trestbps, age)
# (fbs _|_ chol, restecg | heartdisease, exang, sex, thalach, age)
# (fbs _|_ thalach | heartdisease, exang, chol, restecg, trestbps)
# (fbs _|_ thalach | heartdisease, exang, chol, restecg, age)
# (fbs _|_ restecg | heartdisease, exang, chol, trestbps, thalach)
# (fbs _|_ sex, restecg, thalach | heartdisease, exang, chol, trestbps, age)
# (fbs _|_ restecg | heartdisease, exang, chol, thalach, age)
# (fbs _|_ chol | heartdisease, exang, restecg, trestbps, thalach)
# (fbs _|_ chol, sex, thalach | heartdisease, exang, restecg, trestbps, age)
# (fbs _|_ chol | heartdisease, exang, restecg, thalach, age)
# (fbs _|_ chol, sex, restecg | heartdisease, exang, trestbps, thalach, age)
# (fbs _|_ thalach | heartdisease, chol, sex, restecg, trestbps)
# (fbs _|_ thalach | heartdisease, chol, sex, restecg, age)
# (fbs _|_ restecg | heartdisease, chol, sex, trestbps, thalach)
# (fbs _|_ exang, thalach, restecg | heartdisease, chol, sex, trestbps, age)
# (fbs _|_ restecg | heartdisease, chol, sex, thalach, age)
# (fbs _|_ chol | heartdisease, sex, restecg, trestbps, thalach)
# (fbs _|_ exang, thalach, chol | heartdisease, sex, restecg, trestbps, age)
# (fbs _|_ chol | heartdisease, sex, restecg, thalach, age)
# (fbs _|_ exang, chol, restecg | heartdisease, sex, trestbps, thalach, age)
# (fbs _|_ exang, sex, thalach | heartdisease, chol, restecg, trestbps, age)
# (fbs _|_ exang, sex, restecg | heartdisease, chol, trestbps, thalach, age)
# (fbs _|_ exang, sex, chol | heartdisease, restecg, trestbps, thalach, age)
# (fbs _|_ sex | exang, chol, restecg, trestbps, age)
# (fbs _|_ sex | exang, chol, trestbps, thalach, age)
# (fbs _|_ sex | exang, restecg, trestbps, thalach, age)
# (fbs _|_ exang | chol, sex, restecg, trestbps, age)
# (fbs _|_ exang | chol, sex, trestbps, thalach, age)
# (fbs _|_ exang | sex, restecg, trestbps, thalach, age)
# (fbs _|_ exang, sex | chol, restecg, trestbps, thalach, age)
# (fbs _|_ thalach | heartdisease, exang, sex, chol, restecg, trestbps)
# (fbs _|_ thalach | heartdisease, exang, sex, chol, restecg, age)
# (fbs _|_ restecg | heartdisease, exang, sex, chol, trestbps, thalach)
# (fbs _|_ thalach, restecg | heartdisease, exang, sex, chol, trestbps, age)
# (fbs _|_ restecg | heartdisease, exang, sex, chol, thalach, age)
# (fbs _|_ chol | heartdisease, exang, sex, restecg, trestbps, thalach)
# (fbs _|_ chol, thalach | heartdisease, exang, sex, restecg, trestbps, age)
# (fbs _|_ chol | heartdisease, exang, sex, restecg, thalach, age)
# (fbs _|_ chol, restecg | heartdisease, exang, sex, trestbps, thalach, age)
# (fbs _|_ sex, thalach | heartdisease, exang, chol, restecg, trestbps, age)
# (fbs _|_ sex, restecg | heartdisease, exang, chol, trestbps, thalach, age)
# (fbs _|_ chol, sex | heartdisease, exang, restecg, trestbps, thalach, age)
# (fbs _|_ exang, thalach | heartdisease, chol, sex, restecg, trestbps, age)
# (fbs _|_ exang, restecg | heartdisease, chol, sex, trestbps, thalach, age)
# (fbs _|_ exang, chol | heartdisease, sex, restecg, trestbps, thalach, age)
# (fbs _|_ exang, sex | heartdisease, chol, restecg, trestbps, thalach, age)
# (fbs _|_ sex | exang, chol, restecg, trestbps, thalach, age)
# (fbs _|_ exang | chol, sex, restecg, trestbps, thalach, age)
# (fbs _|_ thalach | heartdisease, exang, sex, chol, restecg, trestbps, age)
# (fbs _|_ restecg | heartdisease, exang, sex, chol, trestbps, thalach, age)
# (fbs _|_ chol | heartdisease, exang, sex, restecg, trestbps, thalach, age)
# (fbs _|_ sex | heartdisease, exang, chol, restecg, trestbps, thalach, age)
# (fbs _|_ exang | heartdisease, chol, sex, restecg, trestbps, thalach, age)
# (sex _|_ fbs, exang, age)
# (sex _|_ exang, age | fbs)
# (sex _|_ chol, thalach, restecg | heartdisease)
# (sex _|_ fbs, age | exang)
# (sex _|_ fbs, exang | age)
# (sex _|_ chol, thalach, restecg | fbs, heartdisease)
# (sex _|_ age | fbs, exang)
# (sex _|_ chol, thalach, restecg, heartdisease | fbs, trestbps)
# (sex _|_ exang | fbs, age)
# (sex _|_ chol, thalach, restecg | exang, heartdisease)
# (sex _|_ thalach, restecg | chol, heartdisease)
# (sex _|_ chol, thalach | restecg, heartdisease)
# (sex _|_ chol, thalach, restecg | trestbps, heartdisease)
# (sex _|_ chol, restecg | thalach, heartdisease)
# (sex _|_ chol, thalach, restecg | age, heartdisease)
# (sex _|_ fbs | exang, age)
# (sex _|_ fbs, restecg, heartdisease, chol, thalach | trestbps, age)
# (sex _|_ chol, thalach, restecg | fbs, exang, heartdisease)
# (sex _|_ thalach, restecg | fbs, chol, heartdisease)
# (sex _|_ chol, thalach | fbs, restecg, heartdisease)
# (sex _|_ chol, thalach, restecg | fbs, trestbps, heartdisease)
# (sex _|_ chol, restecg | fbs, thalach, heartdisease)
# (sex _|_ chol, thalach, restecg | fbs, age, heartdisease)
# (sex _|_ chol, thalach, restecg, heartdisease | fbs, exang, trestbps)
# (sex _|_ thalach, restecg, heartdisease | fbs, chol, trestbps)
# (sex _|_ chol, thalach, heartdisease | fbs, trestbps, restecg)
# ...
# (thalach _|_ exang, chol, restecg | fbs, heartdisease, sex, trestbps, age)
# (thalach _|_ exang, sex, age | fbs, heartdisease, chol, restecg, trestbps)
# (thalach _|_ exang, sex, trestbps | fbs, heartdisease, chol, restecg, age)
# (thalach _|_ exang, sex, restecg | fbs, heartdisease, chol, trestbps, age)
# (thalach _|_ exang, sex, chol | fbs, heartdisease, restecg, trestbps, age)
# (thalach _|_ age | fbs, exang, sex, chol, trestbps)
# (thalach _|_ age | fbs, exang, sex, restecg, trestbps)
# (thalach _|_ sex, age | fbs, exang, chol, restecg, trestbps)
# (thalach _|_ sex | fbs, exang, chol, trestbps, age)
# (thalach _|_ sex | fbs, exang, restecg, trestbps, age)
# (thalach _|_ exang, age | fbs, chol, sex, restecg, trestbps)
# (thalach _|_ exang | fbs, chol, sex, trestbps, age)
# (thalach _|_ exang | fbs, sex, restecg, trestbps, age)
# (thalach _|_ exang, sex | fbs, chol, restecg, trestbps, age)
# (thalach _|_ fbs, trestbps, age | heartdisease, exang, sex, chol, restecg)
# (thalach _|_ fbs, restecg, age | heartdisease, exang, sex, chol, trestbps)
# (thalach _|_ fbs, trestbps, restecg | heartdisease, exang, sex, chol, age)
# (thalach _|_ fbs, chol, age | heartdisease, exang, sex, restecg, trestbps)
# (thalach _|_ fbs, chol, trestbps | heartdisease, exang, sex, restecg, age)
# (thalach _|_ fbs, chol, restecg | heartdisease, exang, sex, trestbps, age)
# (thalach _|_ fbs, sex, age | heartdisease, exang, chol, restecg, trestbps)
# (thalach _|_ fbs, trestbps, sex | heartdisease, exang, chol, restecg, age)
# (thalach _|_ fbs, sex, restecg | heartdisease, exang, chol, trestbps, age)
# (thalach _|_ fbs, chol, sex | heartdisease, exang, restecg, trestbps, age)
# (thalach _|_ fbs, exang, age | heartdisease, chol, sex, restecg, trestbps)
# (thalach _|_ fbs, exang, trestbps | heartdisease, chol, sex, restecg, age)
# (thalach _|_ fbs, exang, restecg | heartdisease, chol, sex, trestbps, age)
# (thalach _|_ fbs, exang, chol | heartdisease, sex, restecg, trestbps, age)
# (thalach _|_ fbs, exang, sex | heartdisease, chol, restecg, trestbps, age)
# (thalach _|_ sex | exang, chol, restecg, trestbps, age)
# (thalach _|_ exang | chol, sex, restecg, trestbps, age)
# (thalach _|_ trestbps, age | fbs, heartdisease, exang, sex, chol, restecg)
# (thalach _|_ restecg, age | fbs, heartdisease, exang, sex, chol, trestbps)
# (thalach _|_ trestbps, restecg | fbs, heartdisease, exang, sex, chol, age)
# (thalach _|_ chol, age | fbs, heartdisease, exang, sex, restecg, trestbps)
# (thalach _|_ chol, trestbps | fbs, heartdisease, exang, sex, restecg, age)
# (thalach _|_ chol, restecg | fbs, heartdisease, exang, sex, trestbps, age)
# (thalach _|_ sex, age | fbs, heartdisease, exang, chol, restecg, trestbps)
# (thalach _|_ trestbps, sex | fbs, heartdisease, exang, chol, restecg, age)
# (thalach _|_ sex, restecg | fbs, heartdisease, exang, chol, trestbps, age)
# (thalach _|_ chol, sex | fbs, heartdisease, exang, restecg, trestbps, age)
# (thalach _|_ exang, age | fbs, heartdisease, chol, sex, restecg, trestbps)
# (thalach _|_ exang, trestbps | fbs, heartdisease, chol, sex, restecg, age)
# (thalach _|_ exang, restecg | fbs, heartdisease, chol, sex, trestbps, age)
# (thalach _|_ exang, chol | fbs, heartdisease, sex, restecg, trestbps, age)
# (thalach _|_ exang, sex | fbs, heartdisease, chol, restecg, trestbps, age)
# (thalach _|_ age | fbs, exang, sex, chol, restecg, trestbps)
# (thalach _|_ sex | fbs, exang, chol, restecg, trestbps, age)
# (thalach _|_ exang | fbs, chol, sex, restecg, trestbps, age)
# (thalach _|_ fbs, age | heartdisease, exang, sex, chol, restecg, trestbps)
# (thalach _|_ fbs, trestbps | heartdisease, exang, sex, chol, restecg, age)
# (thalach _|_ fbs, restecg | heartdisease, exang, sex, chol, trestbps, age)
# (thalach _|_ fbs, chol | heartdisease, exang, sex, restecg, trestbps, age)
# (thalach _|_ fbs, sex | heartdisease, exang, chol, restecg, trestbps, age)
# (thalach _|_ fbs, exang | heartdisease, chol, sex, restecg, trestbps, age)
# (thalach _|_ age | fbs, heartdisease, exang, sex, chol, restecg, trestbps)
# (thalach _|_ trestbps | fbs, heartdisease, exang, sex, chol, restecg, age)
# (thalach _|_ restecg | fbs, heartdisease, exang, sex, chol, trestbps, age)
# (thalach _|_ chol | fbs, heartdisease, exang, sex, restecg, trestbps, age)
# (thalach _|_ sex | fbs, heartdisease, exang, chol, restecg, trestbps, age)
# (thalach _|_ exang | fbs, heartdisease, chol, sex, restecg, trestbps, age)
# (thalach _|_ fbs | heartdisease, exang, sex, chol, restecg, trestbps, age)
# (chol _|_ fbs, trestbps, restecg, thalach, exang, sex, age | heartdisease)
# (chol _|_ trestbps, restecg, thalach, exang, sex, age | fbs, heartdisease)
# (chol _|_ exang, sex, age | fbs, trestbps)
# (chol _|_ fbs, restecg, thalach, trestbps, sex, age | exang, heartdisease)
# (chol _|_ fbs, trestbps, restecg, exang, thalach, age | sex, heartdisease)
# (chol _|_ fbs, trestbps, thalach, exang, sex, age | restecg, heartdisease)
# (chol _|_ fbs, restecg, thalach, exang, sex, age | trestbps, heartdisease)
# (chol _|_ fbs, trestbps, restecg, exang, sex, age | thalach, heartdisease)
# (chol _|_ fbs, trestbps, restecg, thalach, exang, sex | age, heartdisease)
# (chol _|_ exang, sex | trestbps, age)
# (chol _|_ restecg, thalach, trestbps, sex, age | fbs, exang, heartdisease)
# (chol _|_ trestbps, restecg, exang, thalach, age | fbs, sex, heartdisease)
# (chol _|_ trestbps, thalach, exang, sex, age | fbs, restecg, heartdisease)
# (chol _|_ restecg, thalach, exang, sex, age | fbs, trestbps, heartdisease)
# (chol _|_ trestbps, restecg, exang, sex, age | fbs, thalach, heartdisease)
# (chol _|_ trestbps, restecg, thalach, exang, sex | fbs, age, heartdisease)
# (chol _|_ sex, age | fbs, exang, trestbps)
# (chol _|_ exang, age | fbs, trestbps, sex)
# (chol _|_ exang, sex, age | fbs, trestbps, restecg)
# (chol _|_ exang, sex, age | fbs, trestbps, thalach)
# (chol _|_ exang, sex | fbs, trestbps, age)
# (chol _|_ fbs, restecg, trestbps, thalach, age | exang, sex, heartdisease)
# (chol _|_ fbs, thalach, trestbps, sex, age | exang, restecg, heartdisease)
# (chol _|_ fbs, restecg, thalach, sex, age | exang, trestbps, heartdisease)
# (chol _|_ fbs, restecg, trestbps, sex, age | exang, thalach, heartdisease)
# (chol _|_ fbs, restecg, thalach, trestbps, sex | exang, age, heartdisease)
# (chol _|_ fbs, trestbps, exang, thalach, age | sex, restecg, heartdisease)
# (chol _|_ fbs, restecg, exang, thalach, age | trestbps, sex, heartdisease)
# (chol _|_ fbs, trestbps, restecg, exang, age | thalach, sex, heartdisease)
# (chol _|_ fbs, trestbps, restecg, exang, thalach | sex, age, heartdisease)
# (chol _|_ fbs, thalach, exang, sex, age | trestbps, restecg, heartdisease)
# (chol _|_ fbs, trestbps, exang, sex, age | thalach, restecg, heartdisease)
# (chol _|_ fbs, trestbps, thalach, exang, sex | age, restecg, heartdisease)
# (chol _|_ fbs, restecg, exang, sex, age | trestbps, thalach, heartdisease)
# (chol _|_ fbs, restecg, thalach, exang, sex | trestbps, age, heartdisease)
# (chol _|_ fbs, trestbps, restecg, exang, sex | thalach, age, heartdisease)
# (chol _|_ sex | exang, trestbps, age)
# (chol _|_ exang | trestbps, sex, age)
# (chol _|_ exang, sex | age, trestbps, restecg)
# (chol _|_ exang, sex | trestbps, thalach, age)
# (chol _|_ trestbps, thalach, restecg, age | fbs, exang, sex, heartdisease)
# (chol _|_ trestbps, sex, age, thalach | fbs, exang, restecg, heartdisease)
# (chol _|_ sex, restecg, age, thalach | fbs, exang, trestbps, heartdisease)
# (chol _|_ trestbps, sex, restecg, age | fbs, exang, thalach, heartdisease)
# (chol _|_ trestbps, sex, restecg, thalach | fbs, exang, age, heartdisease)
# (chol _|_ exang, thalach, trestbps, age | fbs, sex, restecg, heartdisease)
# (chol _|_ exang, thalach, restecg, age | fbs, trestbps, sex, heartdisease)
# (chol _|_ exang, trestbps, age, restecg | fbs, thalach, sex, heartdisease)
# (chol _|_ exang, thalach, trestbps, restecg | fbs, sex, age, heartdisease)
# (chol _|_ exang, sex, age, thalach | fbs, trestbps, restecg, heartdisease)
# (chol _|_ exang, sex, trestbps, age | fbs, thalach, restecg, heartdisease)
# (chol _|_ exang, sex, trestbps, thalach | age, fbs, restecg, heartdisease)
# (chol _|_ exang, sex, restecg, age | fbs, trestbps, thalach, heartdisease)
# (chol _|_ exang, sex, restecg, thalach | fbs, trestbps, age, heartdisease)
# (chol _|_ exang, sex, trestbps, restecg | fbs, thalach, age, heartdisease)
# (chol _|_ age | fbs, exang, sex, trestbps)
# (chol _|_ sex, age | fbs, exang, trestbps, restecg)
# (chol _|_ sex, age | fbs, exang, thalach, trestbps)
# (chol _|_ sex | fbs, exang, trestbps, age)
# (chol _|_ exang, age | fbs, trestbps, sex, restecg)
# (chol _|_ exang, age | fbs, trestbps, sex, thalach)
# (chol _|_ exang | fbs, trestbps, sex, age)
# (chol _|_ exang, sex, age | fbs, trestbps, thalach, restecg)
# (chol _|_ exang, sex | age, fbs, trestbps, restecg)
# (chol _|_ exang, sex | fbs, trestbps, thalach, age)
# (chol _|_ fbs, trestbps, thalach, age | exang, sex, restecg, heartdisease)
# (chol _|_ fbs, thalach, restecg, age | exang, sex, trestbps, heartdisease)
# (chol _|_ fbs, trestbps, restecg, age | exang, sex, thalach, heartdisease)
# (chol _|_ fbs, trestbps, thalach, restecg | exang, sex, age, heartdisease)
# (chol _|_ fbs, sex, age, thalach | exang, trestbps, restecg, heartdisease)
# (chol _|_ fbs, trestbps, sex, age | exang, thalach, restecg, heartdisease)
# (chol _|_ fbs, trestbps, sex, thalach | age, exang, restecg, heartdisease)
# (chol _|_ fbs, sex, restecg, age | exang, thalach, trestbps, heartdisease)
# (chol _|_ fbs, sex, restecg, thalach | exang, trestbps, age, heartdisease)
# (chol _|_ fbs, trestbps, sex, restecg | exang, thalach, age, heartdisease)
# (chol _|_ fbs, exang, thalach, age | trestbps, sex, restecg, heartdisease)
# (chol _|_ fbs, exang, trestbps, age | thalach, sex, restecg, heartdisease)
# (chol _|_ fbs, exang, thalach, trestbps | age, sex, restecg, heartdisease)
# (chol _|_ fbs, exang, restecg, age | trestbps, sex, thalach, heartdisease)
# (chol _|_ fbs, exang, thalach, restecg | trestbps, sex, age, heartdisease)
# (chol _|_ fbs, exang, trestbps, restecg | thalach, sex, age, heartdisease)
# (chol _|_ fbs, exang, sex, age | trestbps, thalach, restecg, heartdisease)
# (chol _|_ fbs, exang, sex, thalach | age, trestbps, restecg, heartdisease)
# (chol _|_ fbs, exang, sex, trestbps | age, thalach, restecg, heartdisease)
# (chol _|_ fbs, exang, sex, restecg | trestbps, thalach, age, heartdisease)
# (chol _|_ sex | age, exang, trestbps, restecg)
# (chol _|_ sex | exang, thalach, trestbps, age)
# (chol _|_ exang | age, trestbps, sex, restecg)
# (chol _|_ exang | trestbps, sex, age, thalach)
# (chol _|_ exang, sex | age, trestbps, thalach, restecg)
# (chol _|_ trestbps, thalach, age | fbs, heartdisease, exang, sex, restecg)
# (chol _|_ thalach, restecg, age | fbs, heartdisease, exang, sex, trestbps)
# (chol _|_ trestbps, restecg, age | fbs, heartdisease, exang, sex, thalach)
# (chol _|_ trestbps, thalach, restecg | fbs, heartdisease, exang, sex, age)
# (chol _|_ sex, age, thalach | fbs, heartdisease, exang, restecg, trestbps)
# (chol _|_ trestbps, sex, age | fbs, heartdisease, exang, restecg, thalach)
# (chol _|_ trestbps, sex, thalach | fbs, heartdisease, exang, restecg, age)
# (chol _|_ sex, restecg, age | fbs, heartdisease, exang, trestbps, thalach)
# (chol _|_ sex, restecg, thalach | fbs, heartdisease, exang, trestbps, age)
# (chol _|_ trestbps, sex, restecg | fbs, heartdisease, exang, thalach, age)
# (chol _|_ exang, thalach, age | fbs, heartdisease, sex, restecg, trestbps)
# (chol _|_ exang, trestbps, age | fbs, heartdisease, sex, restecg, thalach)
# (chol _|_ exang, thalach, trestbps | fbs, heartdisease, sex, restecg, age)
# (chol _|_ exang, restecg, age | fbs, heartdisease, sex, trestbps, thalach)
# (chol _|_ exang, thalach, restecg | fbs, heartdisease, sex, trestbps, age)
# (chol _|_ exang, trestbps, restecg | fbs, heartdisease, sex, thalach, age)
# (chol _|_ exang, sex, age | fbs, heartdisease, restecg, trestbps, thalach)
# (chol _|_ exang, sex, thalach | fbs, heartdisease, restecg, trestbps, age)
# (chol _|_ exang, sex, trestbps | fbs, heartdisease, restecg, thalach, age)
# (chol _|_ exang, sex, restecg | fbs, heartdisease, trestbps, thalach, age)
# (chol _|_ age | fbs, exang, sex, restecg, trestbps)
# (chol _|_ age | fbs, exang, sex, trestbps, thalach)
# (chol _|_ sex, age | fbs, exang, restecg, trestbps, thalach)
# (chol _|_ sex | fbs, exang, restecg, trestbps, age)
# (chol _|_ sex | fbs, exang, trestbps, thalach, age)
# (chol _|_ exang, age | fbs, sex, restecg, trestbps, thalach)
# (chol _|_ exang | fbs, sex, restecg, trestbps, age)
# (chol _|_ exang | fbs, sex, trestbps, thalach, age)
# (chol _|_ exang, sex | fbs, restecg, trestbps, thalach, age)
# (chol _|_ fbs, thalach, age | heartdisease, exang, sex, restecg, trestbps)
# (chol _|_ fbs, trestbps, age | heartdisease, exang, sex, restecg, thalach)
# (chol _|_ fbs, trestbps, thalach | heartdisease, exang, sex, restecg, age)
# (chol _|_ fbs, restecg, age | heartdisease, exang, sex, trestbps, thalach)
# (chol _|_ fbs, thalach, restecg | heartdisease, exang, sex, trestbps, age)
# (chol _|_ fbs, trestbps, restecg | heartdisease, exang, sex, thalach, age)
# (chol _|_ fbs, sex, age | heartdisease, exang, restecg, trestbps, thalach)
# (chol _|_ fbs, sex, thalach | heartdisease, exang, restecg, trestbps, age)
# (chol _|_ fbs, trestbps, sex | heartdisease, exang, restecg, thalach, age)
# (chol _|_ fbs, sex, restecg | heartdisease, exang, trestbps, thalach, age)
# (chol _|_ fbs, exang, age | heartdisease, sex, restecg, trestbps, thalach)
# (chol _|_ fbs, exang, thalach | heartdisease, sex, restecg, trestbps, age)
# (chol _|_ fbs, exang, trestbps | heartdisease, sex, restecg, thalach, age)
# (chol _|_ fbs, exang, restecg | heartdisease, sex, trestbps, thalach, age)
# (chol _|_ fbs, exang, sex | heartdisease, restecg, trestbps, thalach, age)
# (chol _|_ sex | exang, restecg, trestbps, thalach, age)
# (chol _|_ exang | sex, restecg, trestbps, thalach, age)
# (chol _|_ thalach, age | fbs, heartdisease, exang, sex, restecg, trestbps)
# (chol _|_ trestbps, age | fbs, heartdisease, exang, sex, restecg, thalach)
# (chol _|_ trestbps, thalach | fbs, heartdisease, exang, sex, restecg, age)
# (chol _|_ restecg, age | fbs, heartdisease, exang, sex, trestbps, thalach)
# (chol _|_ thalach, restecg | fbs, heartdisease, exang, sex, trestbps, age)
# (chol _|_ trestbps, restecg | fbs, heartdisease, exang, sex, thalach, age)
# (chol _|_ sex, age | fbs, heartdisease, exang, restecg, trestbps, thalach)
# (chol _|_ sex, thalach | fbs, heartdisease, exang, restecg, trestbps, age)
# (chol _|_ trestbps, sex | fbs, heartdisease, exang, restecg, thalach, age)
# (chol _|_ sex, restecg | fbs, heartdisease, exang, trestbps, thalach, age)
# (chol _|_ exang, age | fbs, heartdisease, sex, restecg, trestbps, thalach)
# (chol _|_ exang, thalach | fbs, heartdisease, sex, restecg, trestbps, age)
# (chol _|_ exang, trestbps | fbs, heartdisease, sex, restecg, thalach, age)
# (chol _|_ exang, restecg | fbs, heartdisease, sex, trestbps, thalach, age)
# (chol _|_ exang, sex | fbs, heartdisease, restecg, trestbps, thalach, age)
# (chol _|_ age | fbs, exang, sex, restecg, trestbps, thalach)
# (chol _|_ sex | fbs, exang, restecg, trestbps, thalach, age)
# (chol _|_ exang | fbs, sex, restecg, trestbps, thalach, age)
# (chol _|_ fbs, age | heartdisease, exang, sex, restecg, trestbps, thalach)
# (chol _|_ fbs, thalach | heartdisease, exang, sex, restecg, trestbps, age)
# (chol _|_ fbs, trestbps | heartdisease, exang, sex, restecg, thalach, age)
# (chol _|_ fbs, restecg | heartdisease, exang, sex, trestbps, thalach, age)
# (chol _|_ fbs, sex | heartdisease, exang, restecg, trestbps, thalach, age)
# (chol _|_ fbs, exang | heartdisease, sex, restecg, trestbps, thalach, age)
# (chol _|_ age | fbs, heartdisease, exang, sex, restecg, trestbps, thalach)
# (chol _|_ thalach | fbs, heartdisease, exang, sex, restecg, trestbps, age)
# (chol _|_ trestbps | fbs, heartdisease, exang, sex, restecg, thalach, age)
# (chol _|_ restecg | fbs, heartdisease, exang, sex, trestbps, thalach, age)
# (chol _|_ sex | fbs, heartdisease, exang, restecg, trestbps, thalach, age)
# (chol _|_ exang | fbs, heartdisease, sex, restecg, trestbps, thalach, age)
# (chol _|_ fbs | heartdisease, exang, sex, restecg, trestbps, thalach, age)

# %%
HeartDisease_infer = VariableElimination(model)

# %%
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'age': 28})
print(q['heartdisease'])
# Out:
# /home/acerroot/anaconda3/lib/python3.8/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:518: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   warn(
# Finding Elimination Order: : 100%|██████████| 7/7 [00:00<00:00, 10519.57it/s]
# Eliminating: sex: 100%|██████████| 7/7 [00:00<00:00, 510.81it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-dfb29116c623> in <module>
#       1 q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'age': 28})
# ----> 2 print(q['heartdisease'])
#
# TypeError: 'DiscreteFactor' object is not subscriptable

# %%
q = HeartDisease_infer.query(variables=['heartdisease'],evidence={'chol': 100})
print(q['heartdisease'])
